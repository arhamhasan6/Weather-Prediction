# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# !from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
import joblib
# Out:
# from: can't read /var/mail/catboost

# %%
df = pd.read_csv("/content/preprocessed_1.csv",on_bad_lines='skip')

# %%
df = df.reset_index()
df.fillna(0, inplace=True)
Y = df["Summary"]
X = df.drop(["Summary"], axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fit the scaler object on the data
scaler.fit(X)

# transform the data to standard scale
X_std = scaler.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size =0.2, stratify = Y, random_state = 0)

# %%
sm=SMOTE(random_state=0)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_res)))
# Out:
# The number of classes before fit Counter({1.0: 9514, 2.0: 7508, 3.0: 4648, 4.0: 3786, 5.0: 1946})
# The number of classes after fit Counter({1.0: 9514, 2.0: 9514, 4.0: 9514, 3.0: 9514, 5.0: 9514})

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
# Create a pipeline for standardization and KNN
pipe = Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsClassifier())])

# Set hyperparameters for KNN
params = {'knn__n_neighbors': [3, 5, 7], 'knn__weights': ['uniform', 'distance']}

# Use grid search to find the best hyperparameters
grid = GridSearchCV(pipe, params, cv=5)
grid.fit(X_train, y_train)

# Get the test accuracy of the model
test_accuracy = grid.score(X_test, y_test)
print("Test accuracy: {:.2f}".format(test_accuracy))
# Out:
# Test accuracy: 0.55

# %%
import tensorflow as tf
import numpy as np

# define the hyperparameters
learning_rate = 0.01
epochs = 100

# define the linear regression model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=(1,))
])

# compile the model with the optimizer and loss function
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
              loss='mean_squared_error')

# train the model for the specified number of epochs
model.fit(X_train, y_train, epochs=100)

# make predictions on new data
y_predT = model.predict(X_test)
print(accuracy_score(y_test,y_predT))
# print the predictions
print(y_pred)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-a531783c9910> in <cell line: 18>()
#      16
#      17 # train the model for the specified number of epochs
# ---> 18 model.fit(X_train, y_train, epochs=100)
#      19
#      20 # make predictions on new data
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1050, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/input_spec.py", line 280, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'sequential_1' (type Sequential).
#
#     Input 0 of layer "dense_1" is incompatible with the layer: expected axis -1 of input shape to have value 1, but received input with shape (None, 8)
#
#     Call arguments received by layer 'sequential_1' (type Sequential):
#       • inputs=tf.Tensor(shape=(None, 8), dtype=float64)
#       • training=True
#       • mask=None

# %%
gnb = GaussianNB()
gnb.fit(X_train_res, y_train_res)
y_pred3 = gnb.predict(X_test)
print(confusion_matrix(y_test,y_pred3))
print(accuracy_score(y_test,y_pred3))
print(classification_report(y_test,y_pred3))
# Out:
# [[1841  226  201   87   23]
#  [1167  353  263   74   20]
#  [ 395  218  399   58   92]
#  [ 586   63  165  105   28]
#  [   0    0   12    9  466]]
# 0.4618303897241279
#               precision    recall  f1-score   support
#
#          1.0       0.46      0.77      0.58      2378
#          2.0       0.41      0.19      0.26      1877
#          3.0       0.38      0.34      0.36      1162
#          4.0       0.32      0.11      0.16       947
#          5.0       0.74      0.96      0.84       487
#
#     accuracy                           0.46      6851
#    macro avg       0.46      0.47      0.44      6851
# weighted avg       0.43      0.46      0.41      6851

# %%
sns.pairplot(df,hue="Summary")

# %%
rf=RandomForestClassifier()
rf.fit(X_train_res,y_train_res)
y_pred1 = rf.predict(X_test)
print(confusion_matrix(y_test,y_pred1))
print(accuracy_score(y_test,y_pred1))
print(classification_report(y_test,y_pred1))
# Out:
# [[1541  442  106  288    1]
#  [ 515 1000  254  108    0]
#  [  70  204  857   31    0]
#  [ 253   74   42  576    2]
#  [   0    0    0    1  486]]
# 0.6509998540359072
#               precision    recall  f1-score   support
#
#          1.0       0.65      0.65      0.65      2378
#          2.0       0.58      0.53      0.56      1877
#          3.0       0.68      0.74      0.71      1162
#          4.0       0.57      0.61      0.59       947
#          5.0       0.99      1.00      1.00       487
#
#     accuracy                           0.65      6851
#    macro avg       0.70      0.70      0.70      6851
# weighted avg       0.65      0.65      0.65      6851

# %%
xgb = XGBClassifier()
import numpy as np

# Convert the target variable to integer

y = y_train_res.astype(int)
y_mapped = y - 1
xgb.fit(X_train_res, y_mapped)
y_pred6 = xgb.predict(X_test)
print(confusion_matrix(y_test.astype(int),y_pred6))
print(accuracy_score(y_test.astype(int),y_pred6))
print(classification_report(y_test.astype(int),y_pred6))
# Out:
# [[   0    0    0    0    0    0]
#  [2249  386   97  260    0    0]
#  [ 462 1502  267  122    0    0]
#  [  88  171 1181   23    0    0]
#  [ 189   50   31  898    0    0]
#  [   0    0    0    0  587    0]]
# 0.07894429522363658
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.18      0.13      0.15      2992
#            2       0.17      0.11      0.14      2353
#            3       0.02      0.02      0.02      1463
#            4       0.00      0.00      0.00      1168
#            5       0.00      0.00      0.00       587
#
#     accuracy                           0.08      8563
#    macro avg       0.06      0.04      0.05      8563
# weighted avg       0.11      0.08      0.09      8563
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc = SVC()
svc.fit(X_train_res, y_train_res)
y_pred5 = svc.predict(X_test)
print(confusion_matrix(y_test,y_pred5))
print(accuracy_score(y_test,y_pred5))
print(classification_report(y_test,y_pred5))
# Out:
# [[486 843  13 813 223]
#  [310 745  30 578 214]
#  [239 375  29 307 212]
#  [155 292  11 371 118]
#  [ 92 179   8 107 101]]
# 0.2528098087870384
#               precision    recall  f1-score   support
#
#          1.0       0.38      0.20      0.27      2378
#          2.0       0.31      0.40      0.35      1877
#          3.0       0.32      0.02      0.05      1162
#          4.0       0.17      0.39      0.24       947
#          5.0       0.12      0.21      0.15       487
#
#     accuracy                           0.25      6851
#    macro avg       0.26      0.25      0.21      6851
# weighted avg       0.30      0.25      0.24      6851

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)

# calculate the test accuracy of the model
test_accuracy = lr.score(X_test, y_test)
print("Test accuracy: {:.2f}".format(test_accuracy))
# Out:
# Test accuracy: 0.26

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# Assume X and y are your data and target variables
kf = KFold(n_splits=5, shuffle=True)
lr = LinearRegression()

# Loop over the folds and fit the model
for train_idx, test_idx in kf.split(X):
    X_train, y_train = X.iloc[train_idx], Y.iloc[train_idx]
    X_test, y_test = X.iloc[test_idx], Y.iloc[test_idx]
    lr.fit(X_train, y_train)
    score = lr.score(X_test, y_test)
    print("Accuracy:", score)
# Out:
# Accuracy: 0.24658937149295546
# Accuracy: 0.25573040095256794
# Accuracy: 0.2722780992752484
# Accuracy: 0.2788099130575148
# Accuracy: 0.2725546771131766

# %%
from sklearn.model_selection import KFold
from sklearn.neural_network import MLPClassifier

# Define the model with hyperparameters
model = MLPClassifier(learning_rate_init=0.001, max_iter=3000)

# Define the number of folds for k-fold cross-validation
k = 4
kf = KFold(n_splits=k, shuffle=True)

# Loop over the folds
scores = []
for train_idx, test_idx in kf.split(X):
    # Split the data into train and test sets
    X_train, y_train = X.iloc[train_idx], Y.iloc[train_idx]
    X_test, y_test = X.iloc[test_idx], Y.iloc[test_idx]
    
    # Fit the model on the training data
    model.fit(X_train, y_train)
    
    # Evaluate the model on the test data
    score = model.score(X_test, y_test)
    scores.append(score)

# Compute the mean and standard deviation of the scores
mean_score = np.mean(scores)
std_score = np.std(scores)

print(f"Mean accuracy: {mean_score:.3f} +/- {std_score:.3f}")
# Out:
# Mean accuracy: 0.341 +/- 0.087

# %%
logreg = LogisticRegression()
logreg.fit(X_train_res, y_train_res)
y_pred2 = logreg.predict(X_test)
print(confusion_matrix(y_test,y_pred2))
print(accuracy_score(y_test,y_pred2))
print(classification_report(y_test,y_pred2))
# Out:
# [[1206  429  225  349  140]
#  [ 825  330  284  306  166]
#  [ 297  207  262  131  260]
#  [ 408  141   71  177  158]
#  [  23   24   21   11  399]]
# 0.3465693430656934
#               precision    recall  f1-score   support
#
#          1.0       0.44      0.51      0.47      2349
#          2.0       0.29      0.17      0.22      1911
#          3.0       0.30      0.23      0.26      1157
#          4.0       0.18      0.19      0.18       955
#          5.0       0.36      0.83      0.50       478
#
#     accuracy                           0.35      6850
#    macro avg       0.31      0.39      0.33      6850
# weighted avg       0.33      0.35      0.33      6850
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# !pip install catboost
from catboost import CatBoostClassifier
cat = CatBoostClassifier(iterations=3000, eval_metric = "AUC")
cat.fit(X_train_res, y_train_res)
y_pred = cat.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.2)
# Learning rate set to 0.03808
# 0:	total: 31.9ms	remaining: 1m 35s
# 1:	total: 60.2ms	remaining: 1m 30s
# 2:	total: 86.4ms	remaining: 1m 26s
# 3:	total: 108ms	remaining: 1m 20s
# 4:	total: 139ms	remaining: 1m 23s
# 5:	total: 161ms	remaining: 1m 20s
# 6:	total: 184ms	remaining: 1m 18s
# 7:	total: 211ms	remaining: 1m 18s
# 8:	total: 232ms	remaining: 1m 17s
# 9:	total: 255ms	remaining: 1m 16s
# 10:	total: 278ms	remaining: 1m 15s
# 11:	total: 300ms	remaining: 1m 14s
# 12:	total: 323ms	remaining: 1m 14s
# 13:	total: 346ms	remaining: 1m 13s
# 14:	total: 369ms	remaining: 1m 13s
# 15:	total: 390ms	remaining: 1m 12s
# 16:	total: 417ms	remaining: 1m 13s
# 17:	total: 439ms	remaining: 1m 12s
# 18:	total: 461ms	remaining: 1m 12s
# 19:	total: 484ms	remaining: 1m 12s
# 20:	total: 508ms	remaining: 1m 12s
# 21:	total: 536ms	remaining: 1m 12s
# 22:	total: 565ms	remaining: 1m 13s
# 23:	total: 586ms	remaining: 1m 12s
# 24:	total: 608ms	remaining: 1m 12s
# 25:	total: 634ms	remaining: 1m 12s
# 26:	total: 657ms	remaining: 1m 12s
# 27:	total: 678ms	remaining: 1m 11s
# 28:	total: 700ms	remaining: 1m 11s
# 29:	total: 722ms	remaining: 1m 11s
# 30:	total: 743ms	remaining: 1m 11s
# 31:	total: 766ms	remaining: 1m 11s
# 32:	total: 789ms	remaining: 1m 10s
# 33:	total: 810ms	remaining: 1m 10s
# 34:	total: 832ms	remaining: 1m 10s
# 35:	total: 859ms	remaining: 1m 10s
# 36:	total: 882ms	remaining: 1m 10s
# 37:	total: 904ms	remaining: 1m 10s
# 38:	total: 926ms	remaining: 1m 10s
# 39:	total: 961ms	remaining: 1m 11s
# 40:	total: 982ms	remaining: 1m 10s
# 41:	total: 1s	remaining: 1m 10s
# 42:	total: 1.02s	remaining: 1m 10s
# 43:	total: 1.05s	remaining: 1m 10s
# 44:	total: 1.07s	remaining: 1m 10s
# 45:	total: 1.09s	remaining: 1m 10s
# 46:	total: 1.11s	remaining: 1m 10s
# 47:	total: 1.14s	remaining: 1m 9s
# 48:	total: 1.16s	remaining: 1m 9s
# 49:	total: 1.18s	remaining: 1m 9s
# 50:	total: 1.2s	remaining: 1m 9s
# 51:	total: 1.22s	remaining: 1m 9s
# 52:	total: 1.24s	remaining: 1m 9s
# 53:	total: 1.26s	remaining: 1m 8s
# 54:	total: 1.29s	remaining: 1m 8s
# 55:	total: 1.31s	remaining: 1m 8s
# 56:	total: 1.34s	remaining: 1m 8s
# 57:	total: 1.36s	remaining: 1m 8s
# 58:	total: 1.38s	remaining: 1m 8s
# 59:	total: 1.4s	remaining: 1m 8s
# 60:	total: 1.42s	remaining: 1m 8s
# 61:	total: 1.44s	remaining: 1m 8s
# 62:	total: 1.46s	remaining: 1m 8s
# 63:	total: 1.48s	remaining: 1m 8s
# 64:	total: 1.51s	remaining: 1m 8s
# 65:	total: 1.53s	remaining: 1m 8s
# 66:	total: 1.56s	remaining: 1m 8s
# 67:	total: 1.58s	remaining: 1m 8s
# 68:	total: 1.6s	remaining: 1m 7s
# 69:	total: 1.62s	remaining: 1m 7s
# 70:	total: 1.64s	remaining: 1m 7s
# 71:	total: 1.66s	remaining: 1m 7s
# 72:	total: 1.69s	remaining: 1m 7s
# 73:	total: 1.71s	remaining: 1m 7s
# 74:	total: 1.73s	remaining: 1m 7s
# 75:	total: 1.76s	remaining: 1m 7s
# 76:	total: 1.78s	remaining: 1m 7s
# 77:	total: 1.8s	remaining: 1m 7s
# 78:	total: 1.82s	remaining: 1m 7s
# 79:	total: 1.84s	remaining: 1m 7s
# 80:	total: 1.87s	remaining: 1m 7s
# 81:	total: 1.89s	remaining: 1m 7s
# 82:	total: 1.91s	remaining: 1m 7s
# 83:	total: 1.94s	remaining: 1m 7s
# 84:	total: 1.96s	remaining: 1m 7s
# 85:	total: 1.98s	remaining: 1m 6s
# 86:	total: 2s	remaining: 1m 6s
# 87:	total: 2.02s	remaining: 1m 6s
# 88:	total: 2.04s	remaining: 1m 6s
# 89:	total: 2.06s	remaining: 1m 6s
# 90:	total: 2.08s	remaining: 1m 6s
# 91:	total: 2.1s	remaining: 1m 6s
# 92:	total: 2.13s	remaining: 1m 6s
# 93:	total: 2.15s	remaining: 1m 6s
# 94:	total: 2.17s	remaining: 1m 6s
# 95:	total: 2.2s	remaining: 1m 6s
# 96:	total: 2.22s	remaining: 1m 6s
# 97:	total: 2.24s	remaining: 1m 6s
# 98:	total: 2.26s	remaining: 1m 6s
# 99:	total: 2.28s	remaining: 1m 6s
# 100:	total: 2.3s	remaining: 1m 6s
# 101:	total: 2.32s	remaining: 1m 6s
# 102:	total: 2.35s	remaining: 1m 6s
# 103:	total: 2.37s	remaining: 1m 5s
# 104:	total: 2.39s	remaining: 1m 5s
# 105:	total: 2.41s	remaining: 1m 5s
# 106:	total: 2.43s	remaining: 1m 5s
# 107:	total: 2.46s	remaining: 1m 5s
# 108:	total: 2.48s	remaining: 1m 5s
# 109:	total: 2.51s	remaining: 1m 5s
# 110:	total: 2.54s	remaining: 1m 6s
# 111:	total: 2.57s	remaining: 1m 6s
# 112:	total: 2.59s	remaining: 1m 6s
# 113:	total: 2.61s	remaining: 1m 6s
# 114:	total: 2.63s	remaining: 1m 6s
# 115:	total: 2.65s	remaining: 1m 5s
# 116:	total: 2.67s	remaining: 1m 5s
# 117:	total: 2.69s	remaining: 1m 5s
# 118:	total: 2.71s	remaining: 1m 5s
# 119:	total: 2.74s	remaining: 1m 5s
# 120:	total: 2.76s	remaining: 1m 5s
# 121:	total: 2.78s	remaining: 1m 5s
# 122:	total: 2.8s	remaining: 1m 5s
# 123:	total: 2.82s	remaining: 1m 5s
# 124:	total: 2.85s	remaining: 1m 5s
# 125:	total: 2.88s	remaining: 1m 5s
# 126:	total: 2.9s	remaining: 1m 5s
# 127:	total: 2.92s	remaining: 1m 5s
# 128:	total: 2.94s	remaining: 1m 5s
# 129:	total: 2.96s	remaining: 1m 5s
# 130:	total: 2.98s	remaining: 1m 5s
# 131:	total: 3s	remaining: 1m 5s
# 132:	total: 3.03s	remaining: 1m 5s
# 133:	total: 3.05s	remaining: 1m 5s
# 134:	total: 3.07s	remaining: 1m 5s
# 135:	total: 3.09s	remaining: 1m 5s
# 136:	total: 3.11s	remaining: 1m 5s
# 137:	total: 3.13s	remaining: 1m 4s
# 138:	total: 3.15s	remaining: 1m 4s
# 139:	total: 3.18s	remaining: 1m 4s
# 140:	total: 3.2s	remaining: 1m 4s
# 141:	total: 3.22s	remaining: 1m 4s
# 142:	total: 3.24s	remaining: 1m 4s
# 143:	total: 3.26s	remaining: 1m 4s
# 144:	total: 3.29s	remaining: 1m 4s
# 145:	total: 3.31s	remaining: 1m 4s
# 146:	total: 3.33s	remaining: 1m 4s
# 147:	total: 3.35s	remaining: 1m 4s
# 148:	total: 3.38s	remaining: 1m 4s
# 149:	total: 3.4s	remaining: 1m 4s
# 150:	total: 3.42s	remaining: 1m 4s
# 151:	total: 3.44s	remaining: 1m 4s
# 152:	total: 3.47s	remaining: 1m 4s
# 153:	total: 3.49s	remaining: 1m 4s
# 154:	total: 3.51s	remaining: 1m 4s
# 155:	total: 3.53s	remaining: 1m 4s
# 156:	total: 3.55s	remaining: 1m 4s
# 157:	total: 3.58s	remaining: 1m 4s
# 158:	total: 3.6s	remaining: 1m 4s
# 159:	total: 3.62s	remaining: 1m 4s
# 160:	total: 3.65s	remaining: 1m 4s
# 161:	total: 3.67s	remaining: 1m 4s
# 162:	total: 3.69s	remaining: 1m 4s
# 163:	total: 3.71s	remaining: 1m 4s
# 164:	total: 3.73s	remaining: 1m 4s
# 165:	total: 3.76s	remaining: 1m 4s
# 166:	total: 3.78s	remaining: 1m 4s
# 167:	total: 3.8s	remaining: 1m 4s
# 168:	total: 3.82s	remaining: 1m 4s
# 169:	total: 3.84s	remaining: 1m 3s
# 170:	total: 3.87s	remaining: 1m 3s
# 171:	total: 3.88s	remaining: 1m 3s
# 172:	total: 3.91s	remaining: 1m 3s
# 173:	total: 3.93s	remaining: 1m 3s
# 174:	total: 3.94s	remaining: 1m 3s
# 175:	total: 3.97s	remaining: 1m 3s
# 176:	total: 3.99s	remaining: 1m 3s
# 177:	total: 4.02s	remaining: 1m 3s
# 178:	total: 4.04s	remaining: 1m 3s
# 179:	total: 4.06s	remaining: 1m 3s
# 180:	total: 4.09s	remaining: 1m 3s
# 181:	total: 4.11s	remaining: 1m 3s
# 182:	total: 4.13s	remaining: 1m 3s
# 183:	total: 4.16s	remaining: 1m 3s
# 184:	total: 4.18s	remaining: 1m 3s
# 185:	total: 4.2s	remaining: 1m 3s
# 186:	total: 4.22s	remaining: 1m 3s
# 187:	total: 4.24s	remaining: 1m 3s
# 188:	total: 4.26s	remaining: 1m 3s
# 189:	total: 4.29s	remaining: 1m 3s
# 190:	total: 4.31s	remaining: 1m 3s
# 191:	total: 4.33s	remaining: 1m 3s
# 192:	total: 4.36s	remaining: 1m 3s
# 193:	total: 4.38s	remaining: 1m 3s
# 194:	total: 4.4s	remaining: 1m 3s
# 195:	total: 4.42s	remaining: 1m 3s
# 196:	total: 4.44s	remaining: 1m 3s
# 197:	total: 4.46s	remaining: 1m 3s
# 198:	total: 4.49s	remaining: 1m 3s
# 199:	total: 4.53s	remaining: 1m 3s
# 200:	total: 4.56s	remaining: 1m 3s
# 201:	total: 4.59s	remaining: 1m 3s
# 202:	total: 4.62s	remaining: 1m 3s
# 203:	total: 4.66s	remaining: 1m 3s
# 204:	total: 4.71s	remaining: 1m 4s
# 205:	total: 4.76s	remaining: 1m 4s
# 206:	total: 4.8s	remaining: 1m 4s
# 207:	total: 4.85s	remaining: 1m 5s
# 208:	total: 4.9s	remaining: 1m 5s
# 209:	total: 4.94s	remaining: 1m 5s
# 210:	total: 4.99s	remaining: 1m 6s
# 211:	total: 5.04s	remaining: 1m 6s
# 212:	total: 5.08s	remaining: 1m 6s
# 213:	total: 5.13s	remaining: 1m 6s
# 214:	total: 5.18s	remaining: 1m 7s
# 215:	total: 5.23s	remaining: 1m 7s
# 216:	total: 5.28s	remaining: 1m 7s
# 217:	total: 5.32s	remaining: 1m 7s
# 218:	total: 5.37s	remaining: 1m 8s
# 219:	total: 5.41s	remaining: 1m 8s
# 220:	total: 5.46s	remaining: 1m 8s
# 221:	total: 5.51s	remaining: 1m 8s
# 222:	total: 5.55s	remaining: 1m 9s
# 223:	total: 5.6s	remaining: 1m 9s
# 224:	total: 5.64s	remaining: 1m 9s
# 225:	total: 5.69s	remaining: 1m 9s
# 226:	total: 5.74s	remaining: 1m 10s
# 227:	total: 5.79s	remaining: 1m 10s
# 228:	total: 5.84s	remaining: 1m 10s
# 229:	total: 5.89s	remaining: 1m 10s
# 230:	total: 5.93s	remaining: 1m 11s
# 231:	total: 5.98s	remaining: 1m 11s
# 232:	total: 6.03s	remaining: 1m 11s
# 233:	total: 6.08s	remaining: 1m 11s
# 234:	total: 6.12s	remaining: 1m 12s
# 235:	total: 6.17s	remaining: 1m 12s
# 236:	total: 6.21s	remaining: 1m 12s
# 237:	total: 6.26s	remaining: 1m 12s
# 238:	total: 6.3s	remaining: 1m 12s
# 239:	total: 6.34s	remaining: 1m 12s
# 240:	total: 6.36s	remaining: 1m 12s
# 241:	total: 6.38s	remaining: 1m 12s
# 242:	total: 6.41s	remaining: 1m 12s
# 243:	total: 6.44s	remaining: 1m 12s
# 244:	total: 6.46s	remaining: 1m 12s
# 245:	total: 6.48s	remaining: 1m 12s
# 246:	total: 6.5s	remaining: 1m 12s
# 247:	total: 6.52s	remaining: 1m 12s
# 248:	total: 6.54s	remaining: 1m 12s
# 249:	total: 6.57s	remaining: 1m 12s
# 250:	total: 6.6s	remaining: 1m 12s
# 251:	total: 6.62s	remaining: 1m 12s
# 252:	total: 6.64s	remaining: 1m 12s
# 253:	total: 6.66s	remaining: 1m 12s
# 254:	total: 6.68s	remaining: 1m 11s
# 255:	total: 6.71s	remaining: 1m 11s
# 256:	total: 6.72s	remaining: 1m 11s
# 257:	total: 6.74s	remaining: 1m 11s
# 258:	total: 6.76s	remaining: 1m 11s
# 259:	total: 6.78s	remaining: 1m 11s
# 260:	total: 6.81s	remaining: 1m 11s
# 261:	total: 6.83s	remaining: 1m 11s
# 262:	total: 6.85s	remaining: 1m 11s
# 263:	total: 6.87s	remaining: 1m 11s
# 264:	total: 6.9s	remaining: 1m 11s
# 265:	total: 6.92s	remaining: 1m 11s
# 266:	total: 6.94s	remaining: 1m 11s
# 267:	total: 6.96s	remaining: 1m 10s
# 268:	total: 6.99s	remaining: 1m 10s
# 269:	total: 7.01s	remaining: 1m 10s
# 270:	total: 7.04s	remaining: 1m 10s
# 271:	total: 7.06s	remaining: 1m 10s
# 272:	total: 7.08s	remaining: 1m 10s
# 273:	total: 7.1s	remaining: 1m 10s
# 274:	total: 7.12s	remaining: 1m 10s
# 275:	total: 7.14s	remaining: 1m 10s
# 276:	total: 7.16s	remaining: 1m 10s
# 277:	total: 7.18s	remaining: 1m 10s
# 278:	total: 7.21s	remaining: 1m 10s
# 279:	total: 7.23s	remaining: 1m 10s
# 280:	total: 7.25s	remaining: 1m 10s
# 281:	total: 7.28s	remaining: 1m 10s
# 282:	total: 7.3s	remaining: 1m 10s
# 283:	total: 7.32s	remaining: 1m 9s
# 284:	total: 7.34s	remaining: 1m 9s
# 285:	total: 7.36s	remaining: 1m 9s
# 286:	total: 7.38s	remaining: 1m 9s
# 287:	total: 7.4s	remaining: 1m 9s
# 288:	total: 7.42s	remaining: 1m 9s
# 289:	total: 7.45s	remaining: 1m 9s
# 290:	total: 7.47s	remaining: 1m 9s
# 291:	total: 7.5s	remaining: 1m 9s
# 292:	total: 7.53s	remaining: 1m 9s
# 293:	total: 7.54s	remaining: 1m 9s
# 294:	total: 7.57s	remaining: 1m 9s
# 295:	total: 7.59s	remaining: 1m 9s
# 296:	total: 7.61s	remaining: 1m 9s
# 297:	total: 7.63s	remaining: 1m 9s
# 298:	total: 7.66s	remaining: 1m 9s
# 299:	total: 7.68s	remaining: 1m 9s
# 300:	total: 7.7s	remaining: 1m 9s
# 301:	total: 7.72s	remaining: 1m 9s
# 302:	total: 7.75s	remaining: 1m 8s
# 303:	total: 7.77s	remaining: 1m 8s
# 304:	total: 7.79s	remaining: 1m 8s
# 305:	total: 7.81s	remaining: 1m 8s
# 306:	total: 7.83s	remaining: 1m 8s
# 307:	total: 7.85s	remaining: 1m 8s
# 308:	total: 7.87s	remaining: 1m 8s
# 309:	total: 7.89s	remaining: 1m 8s
# 310:	total: 7.91s	remaining: 1m 8s
# 311:	total: 7.94s	remaining: 1m 8s
# 312:	total: 7.96s	remaining: 1m 8s
# 313:	total: 7.98s	remaining: 1m 8s
# 314:	total: 8.01s	remaining: 1m 8s
# 315:	total: 8.03s	remaining: 1m 8s
# 316:	total: 8.05s	remaining: 1m 8s
# 317:	total: 8.08s	remaining: 1m 8s
# 318:	total: 8.1s	remaining: 1m 8s
# 319:	total: 8.12s	remaining: 1m 8s
# 320:	total: 8.14s	remaining: 1m 7s
# 321:	total: 8.16s	remaining: 1m 7s
# 322:	total: 8.18s	remaining: 1m 7s
# 323:	total: 8.21s	remaining: 1m 7s
# 324:	total: 8.23s	remaining: 1m 7s
# 325:	total: 8.25s	remaining: 1m 7s
# 326:	total: 8.27s	remaining: 1m 7s
# 327:	total: 8.3s	remaining: 1m 7s
# 328:	total: 8.32s	remaining: 1m 7s
# 329:	total: 8.35s	remaining: 1m 7s
# 330:	total: 8.37s	remaining: 1m 7s
# 331:	total: 8.39s	remaining: 1m 7s
# 332:	total: 8.41s	remaining: 1m 7s
# 333:	total: 8.43s	remaining: 1m 7s
# 334:	total: 8.45s	remaining: 1m 7s
# 335:	total: 8.47s	remaining: 1m 7s
# 336:	total: 8.49s	remaining: 1m 7s
# 337:	total: 8.52s	remaining: 1m 7s
# 338:	total: 8.54s	remaining: 1m 7s
# 339:	total: 8.56s	remaining: 1m 6s
# 340:	total: 8.59s	remaining: 1m 6s
# 341:	total: 8.61s	remaining: 1m 6s
# 342:	total: 8.63s	remaining: 1m 6s
# 343:	total: 8.65s	remaining: 1m 6s
# 344:	total: 8.67s	remaining: 1m 6s
# 345:	total: 8.69s	remaining: 1m 6s
# 346:	total: 8.72s	remaining: 1m 6s
# 347:	total: 8.74s	remaining: 1m 6s
# 348:	total: 8.76s	remaining: 1m 6s
# 349:	total: 8.78s	remaining: 1m 6s
# 350:	total: 8.8s	remaining: 1m 6s
# 351:	total: 8.83s	remaining: 1m 6s
# 352:	total: 8.85s	remaining: 1m 6s
# 353:	total: 8.87s	remaining: 1m 6s
# 354:	total: 8.89s	remaining: 1m 6s
# 355:	total: 8.91s	remaining: 1m 6s
# 356:	total: 8.93s	remaining: 1m 6s
# 357:	total: 8.95s	remaining: 1m 6s
# 358:	total: 8.97s	remaining: 1m 6s
# 359:	total: 8.99s	remaining: 1m 5s
# 360:	total: 9.01s	remaining: 1m 5s
# 361:	total: 9.04s	remaining: 1m 5s
# 362:	total: 9.06s	remaining: 1m 5s
# 363:	total: 9.08s	remaining: 1m 5s
# 364:	total: 9.11s	remaining: 1m 5s
# 365:	total: 9.13s	remaining: 1m 5s
# 366:	total: 9.15s	remaining: 1m 5s
# 367:	total: 9.17s	remaining: 1m 5s
# 368:	total: 9.19s	remaining: 1m 5s
# 369:	total: 9.21s	remaining: 1m 5s
# 370:	total: 9.23s	remaining: 1m 5s
# 371:	total: 9.25s	remaining: 1m 5s
# 372:	total: 9.27s	remaining: 1m 5s
# 373:	total: 9.29s	remaining: 1m 5s
# 374:	total: 9.31s	remaining: 1m 5s
# 375:	total: 9.34s	remaining: 1m 5s
# 376:	total: 9.36s	remaining: 1m 5s
# 377:	total: 9.38s	remaining: 1m 5s
# 378:	total: 9.4s	remaining: 1m 5s
# 379:	total: 9.42s	remaining: 1m 4s
# 380:	total: 9.44s	remaining: 1m 4s
# 381:	total: 9.47s	remaining: 1m 4s
# 382:	total: 9.49s	remaining: 1m 4s
# 383:	total: 9.51s	remaining: 1m 4s
# 384:	total: 9.53s	remaining: 1m 4s
# 385:	total: 9.55s	remaining: 1m 4s
# 386:	total: 9.58s	remaining: 1m 4s
# 387:	total: 9.61s	remaining: 1m 4s
# 388:	total: 9.63s	remaining: 1m 4s
# 389:	total: 9.65s	remaining: 1m 4s
# 390:	total: 9.67s	remaining: 1m 4s
# 391:	total: 9.69s	remaining: 1m 4s
# 392:	total: 9.71s	remaining: 1m 4s
# 393:	total: 9.73s	remaining: 1m 4s
# 394:	total: 9.76s	remaining: 1m 4s
# 395:	total: 9.78s	remaining: 1m 4s
# 396:	total: 9.8s	remaining: 1m 4s
# 397:	total: 9.83s	remaining: 1m 4s
# 398:	total: 9.85s	remaining: 1m 4s
# 399:	total: 9.87s	remaining: 1m 4s
# 400:	total: 9.89s	remaining: 1m 4s
# 401:	total: 9.91s	remaining: 1m 4s
# 402:	total: 9.93s	remaining: 1m 3s
# 403:	total: 9.96s	remaining: 1m 3s
# 404:	total: 9.98s	remaining: 1m 3s
# 405:	total: 10s	remaining: 1m 3s
# 406:	total: 10s	remaining: 1m 3s
# 407:	total: 10s	remaining: 1m 3s
# 408:	total: 10.1s	remaining: 1m 3s
# 409:	total: 10.1s	remaining: 1m 3s
# 410:	total: 10.1s	remaining: 1m 3s
# 411:	total: 10.1s	remaining: 1m 3s
# 412:	total: 10.2s	remaining: 1m 3s
# 413:	total: 10.2s	remaining: 1m 3s
# 414:	total: 10.2s	remaining: 1m 3s
# 415:	total: 10.2s	remaining: 1m 3s
# 416:	total: 10.2s	remaining: 1m 3s
# 417:	total: 10.3s	remaining: 1m 3s
# 418:	total: 10.3s	remaining: 1m 3s
# 419:	total: 10.3s	remaining: 1m 3s
# 420:	total: 10.3s	remaining: 1m 3s
# 421:	total: 10.4s	remaining: 1m 3s
# 422:	total: 10.4s	remaining: 1m 3s
# 423:	total: 10.4s	remaining: 1m 3s
# 424:	total: 10.4s	remaining: 1m 3s
# 425:	total: 10.4s	remaining: 1m 3s
# 426:	total: 10.5s	remaining: 1m 3s
# 427:	total: 10.5s	remaining: 1m 2s
# 428:	total: 10.5s	remaining: 1m 2s
# 429:	total: 10.5s	remaining: 1m 2s
# 430:	total: 10.5s	remaining: 1m 2s
# 431:	total: 10.6s	remaining: 1m 2s
# 432:	total: 10.6s	remaining: 1m 2s
# 433:	total: 10.6s	remaining: 1m 2s
# 434:	total: 10.6s	remaining: 1m 2s
# 435:	total: 10.7s	remaining: 1m 2s
# 436:	total: 10.7s	remaining: 1m 2s
# 437:	total: 10.7s	remaining: 1m 2s
# 438:	total: 10.7s	remaining: 1m 2s
# 439:	total: 10.8s	remaining: 1m 2s
# 440:	total: 10.8s	remaining: 1m 2s
# 441:	total: 10.8s	remaining: 1m 2s
# 442:	total: 10.8s	remaining: 1m 2s
# 443:	total: 10.9s	remaining: 1m 2s
# 444:	total: 10.9s	remaining: 1m 2s
# 445:	total: 10.9s	remaining: 1m 2s
# 446:	total: 10.9s	remaining: 1m 2s
# 447:	total: 10.9s	remaining: 1m 2s
# 448:	total: 11s	remaining: 1m 2s
# 449:	total: 11s	remaining: 1m 2s
# 450:	total: 11s	remaining: 1m 2s
# 451:	total: 11s	remaining: 1m 2s
# 452:	total: 11.1s	remaining: 1m 2s
# 453:	total: 11.1s	remaining: 1m 2s
# 454:	total: 11.1s	remaining: 1m 2s
# 455:	total: 11.1s	remaining: 1m 2s
# 456:	total: 11.1s	remaining: 1m 2s
# 457:	total: 11.2s	remaining: 1m 1s
# 458:	total: 11.2s	remaining: 1m 1s
# 459:	total: 11.2s	remaining: 1m 1s
# 460:	total: 11.2s	remaining: 1m 1s
# 461:	total: 11.2s	remaining: 1m 1s
# 462:	total: 11.3s	remaining: 1m 1s
# 463:	total: 11.3s	remaining: 1m 1s
# 464:	total: 11.3s	remaining: 1m 1s
# 465:	total: 11.3s	remaining: 1m 1s
# 466:	total: 11.3s	remaining: 1m 1s
# 467:	total: 11.4s	remaining: 1m 1s
# 468:	total: 11.4s	remaining: 1m 1s
# 469:	total: 11.4s	remaining: 1m 1s
# 470:	total: 11.4s	remaining: 1m 1s
# 471:	total: 11.5s	remaining: 1m 1s
# 472:	total: 11.5s	remaining: 1m 1s
# 473:	total: 11.5s	remaining: 1m 1s
# 474:	total: 11.5s	remaining: 1m 1s
# 475:	total: 11.5s	remaining: 1m 1s
# 476:	total: 11.6s	remaining: 1m 1s
# 477:	total: 11.6s	remaining: 1m 1s
# 478:	total: 11.6s	remaining: 1m 1s
# 479:	total: 11.6s	remaining: 1m 1s
# 480:	total: 11.7s	remaining: 1m 1s
# 481:	total: 11.7s	remaining: 1m 1s
# 482:	total: 11.7s	remaining: 1m 1s
# 483:	total: 11.7s	remaining: 1m
# 484:	total: 11.8s	remaining: 1m
# 485:	total: 11.8s	remaining: 1m
# 486:	total: 11.8s	remaining: 1m
# 487:	total: 11.8s	remaining: 1m
# 488:	total: 11.8s	remaining: 1m
# 489:	total: 11.9s	remaining: 1m
# 490:	total: 11.9s	remaining: 1m
# 491:	total: 11.9s	remaining: 1m
# 492:	total: 11.9s	remaining: 1m
# 493:	total: 11.9s	remaining: 1m
# 494:	total: 12s	remaining: 1m
# 495:	total: 12s	remaining: 1m
# 496:	total: 12s	remaining: 1m
# 497:	total: 12s	remaining: 1m
# 498:	total: 12s	remaining: 1m
# 499:	total: 12.1s	remaining: 1m
# 500:	total: 12.1s	remaining: 1m
# 501:	total: 12.1s	remaining: 1m
# 502:	total: 12.1s	remaining: 1m
# 503:	total: 12.2s	remaining: 1m
# 504:	total: 12.2s	remaining: 1m
# 505:	total: 12.2s	remaining: 1m
# 506:	total: 12.2s	remaining: 1m
# 507:	total: 12.2s	remaining: 1m
# 508:	total: 12.3s	remaining: 1m
# 509:	total: 12.3s	remaining: 60s
# 510:	total: 12.3s	remaining: 59.9s
# 511:	total: 12.3s	remaining: 59.9s
# 512:	total: 12.4s	remaining: 59.9s
# 513:	total: 12.4s	remaining: 59.9s
# 514:	total: 12.4s	remaining: 59.8s
# 515:	total: 12.4s	remaining: 59.8s
# 516:	total: 12.4s	remaining: 59.7s
# 517:	total: 12.5s	remaining: 59.7s
# 518:	total: 12.5s	remaining: 59.7s
# 519:	total: 12.5s	remaining: 59.6s
# 520:	total: 12.5s	remaining: 59.6s
# 521:	total: 12.5s	remaining: 59.6s
# 522:	total: 12.6s	remaining: 59.5s
# 523:	total: 12.6s	remaining: 59.6s
# 524:	total: 12.6s	remaining: 59.5s
# 525:	total: 12.7s	remaining: 59.5s
# 526:	total: 12.7s	remaining: 59.5s
# 527:	total: 12.7s	remaining: 59.4s
# 528:	total: 12.7s	remaining: 59.4s
# 529:	total: 12.7s	remaining: 59.4s
# 530:	total: 12.8s	remaining: 59.4s
# 531:	total: 12.8s	remaining: 59.3s
# 532:	total: 12.8s	remaining: 59.3s
# 533:	total: 12.8s	remaining: 59.3s
# 534:	total: 12.9s	remaining: 59.2s
# 535:	total: 12.9s	remaining: 59.2s
# 536:	total: 12.9s	remaining: 59.2s
# 537:	total: 12.9s	remaining: 59.1s
# 538:	total: 12.9s	remaining: 59.1s
# 539:	total: 13s	remaining: 59s
# 540:	total: 13s	remaining: 59s
# 541:	total: 13s	remaining: 59s
# 542:	total: 13s	remaining: 58.9s
# 543:	total: 13s	remaining: 58.9s
# 544:	total: 13.1s	remaining: 58.9s
# 545:	total: 13.1s	remaining: 58.8s
# 546:	total: 13.1s	remaining: 58.8s
# 547:	total: 13.1s	remaining: 58.8s
# 548:	total: 13.2s	remaining: 58.7s
# 549:	total: 13.2s	remaining: 58.7s
# 550:	total: 13.2s	remaining: 58.7s
# 551:	total: 13.2s	remaining: 58.6s
# 552:	total: 13.2s	remaining: 58.6s
# 553:	total: 13.3s	remaining: 58.6s
# 554:	total: 13.3s	remaining: 58.5s
# 555:	total: 13.3s	remaining: 58.5s
# 556:	total: 13.3s	remaining: 58.5s
# 557:	total: 13.4s	remaining: 58.5s
# 558:	total: 13.4s	remaining: 58.4s
# 559:	total: 13.4s	remaining: 58.4s
# 560:	total: 13.4s	remaining: 58.4s
# 561:	total: 13.4s	remaining: 58.3s
# 562:	total: 13.5s	remaining: 58.3s
# 563:	total: 13.5s	remaining: 58.3s
# 564:	total: 13.5s	remaining: 58.2s
# 565:	total: 13.5s	remaining: 58.2s
# 566:	total: 13.5s	remaining: 58.1s
# 567:	total: 13.6s	remaining: 58.1s
# 568:	total: 13.6s	remaining: 58.1s
# 569:	total: 13.6s	remaining: 58.1s
# 570:	total: 13.7s	remaining: 58.1s
# 571:	total: 13.7s	remaining: 58.1s
# 572:	total: 13.7s	remaining: 58.1s
# 573:	total: 13.7s	remaining: 58s
# 574:	total: 13.7s	remaining: 58s
# 575:	total: 13.8s	remaining: 57.9s
# 576:	total: 13.8s	remaining: 57.9s
# 577:	total: 13.8s	remaining: 57.9s
# 578:	total: 13.8s	remaining: 57.8s
# 579:	total: 13.9s	remaining: 57.8s
# 580:	total: 13.9s	remaining: 57.8s
# 581:	total: 13.9s	remaining: 57.8s
# 582:	total: 13.9s	remaining: 57.8s
# 583:	total: 14s	remaining: 57.7s
# 584:	total: 14s	remaining: 57.7s
# 585:	total: 14s	remaining: 57.7s
# 586:	total: 14s	remaining: 57.6s
# 587:	total: 14s	remaining: 57.6s
# 588:	total: 14.1s	remaining: 57.6s
# 589:	total: 14.1s	remaining: 57.5s
# 590:	total: 14.1s	remaining: 57.5s
# 591:	total: 14.1s	remaining: 57.5s
# 592:	total: 14.1s	remaining: 57.4s
# 593:	total: 14.2s	remaining: 57.4s
# 594:	total: 14.2s	remaining: 57.4s
# 595:	total: 14.2s	remaining: 57.3s
# 596:	total: 14.2s	remaining: 57.3s
# 597:	total: 14.3s	remaining: 57.3s
# 598:	total: 14.3s	remaining: 57.3s
# 599:	total: 14.3s	remaining: 57.2s
# 600:	total: 14.3s	remaining: 57.2s
# 601:	total: 14.3s	remaining: 57.1s
# 602:	total: 14.4s	remaining: 57.1s
# 603:	total: 14.4s	remaining: 57.1s
# 604:	total: 14.4s	remaining: 57s
# 605:	total: 14.4s	remaining: 57s
# 606:	total: 14.4s	remaining: 57s
# 607:	total: 14.5s	remaining: 56.9s
# 608:	total: 14.5s	remaining: 56.9s
# 609:	total: 14.5s	remaining: 56.9s
# 610:	total: 14.5s	remaining: 56.8s
# 611:	total: 14.6s	remaining: 56.8s
# 612:	total: 14.6s	remaining: 56.8s
# 613:	total: 14.6s	remaining: 56.8s
# 614:	total: 14.6s	remaining: 56.7s
# 615:	total: 14.7s	remaining: 56.7s
# 616:	total: 14.7s	remaining: 56.7s
# 617:	total: 14.7s	remaining: 56.7s
# 618:	total: 14.7s	remaining: 56.6s
# 619:	total: 14.7s	remaining: 56.6s
# 620:	total: 14.8s	remaining: 56.6s
# 621:	total: 14.8s	remaining: 56.5s
# 622:	total: 14.8s	remaining: 56.5s
# 623:	total: 14.8s	remaining: 56.5s
# 624:	total: 14.8s	remaining: 56.4s
# 625:	total: 14.9s	remaining: 56.4s
# 626:	total: 14.9s	remaining: 56.4s
# 627:	total: 14.9s	remaining: 56.3s
# 628:	total: 14.9s	remaining: 56.3s
# 629:	total: 15s	remaining: 56.2s
# 630:	total: 15s	remaining: 56.2s
# 631:	total: 15s	remaining: 56.2s
# 632:	total: 15s	remaining: 56.1s
# 633:	total: 15s	remaining: 56.1s
# 634:	total: 15.1s	remaining: 56.1s
# 635:	total: 15.1s	remaining: 56s
# 636:	total: 15.1s	remaining: 56s
# 637:	total: 15.1s	remaining: 56s
# 638:	total: 15.1s	remaining: 55.9s
# 639:	total: 15.2s	remaining: 55.9s
# 640:	total: 15.2s	remaining: 55.9s
# 641:	total: 15.2s	remaining: 55.9s
# 642:	total: 15.2s	remaining: 55.9s
# 643:	total: 15.3s	remaining: 55.8s
# 644:	total: 15.3s	remaining: 55.8s
# 645:	total: 15.3s	remaining: 55.8s
# 646:	total: 15.3s	remaining: 55.8s
# 647:	total: 15.4s	remaining: 55.7s
# 648:	total: 15.4s	remaining: 55.7s
# 649:	total: 15.4s	remaining: 55.7s
# 650:	total: 15.4s	remaining: 55.6s
# 651:	total: 15.4s	remaining: 55.6s
# 652:	total: 15.5s	remaining: 55.6s
# 653:	total: 15.5s	remaining: 55.5s
# 654:	total: 15.5s	remaining: 55.5s
# 655:	total: 15.5s	remaining: 55.5s
# 656:	total: 15.6s	remaining: 55.5s
# 657:	total: 15.6s	remaining: 55.5s
# 658:	total: 15.6s	remaining: 55.4s
# 659:	total: 15.6s	remaining: 55.4s
# 660:	total: 15.6s	remaining: 55.4s
# 661:	total: 15.7s	remaining: 55.3s
# 662:	total: 15.7s	remaining: 55.3s
# 663:	total: 15.7s	remaining: 55.3s
# 664:	total: 15.7s	remaining: 55.3s
# 665:	total: 15.8s	remaining: 55.2s
# 666:	total: 15.8s	remaining: 55.2s
# 667:	total: 15.8s	remaining: 55.2s
# 668:	total: 15.8s	remaining: 55.2s
# 669:	total: 15.9s	remaining: 55.1s
# 670:	total: 15.9s	remaining: 55.1s
# 671:	total: 15.9s	remaining: 55.1s
# 672:	total: 15.9s	remaining: 55s
# 673:	total: 15.9s	remaining: 55s
# 674:	total: 16s	remaining: 55s
# 675:	total: 16s	remaining: 55s
# 676:	total: 16s	remaining: 54.9s
# 677:	total: 16s	remaining: 54.9s
# 678:	total: 16s	remaining: 54.9s
# 679:	total: 16.1s	remaining: 54.8s
# 680:	total: 16.1s	remaining: 54.8s
# 681:	total: 16.1s	remaining: 54.8s
# 682:	total: 16.1s	remaining: 54.7s
# 683:	total: 16.2s	remaining: 54.7s
# 684:	total: 16.2s	remaining: 54.7s
# 685:	total: 16.2s	remaining: 54.6s
# 686:	total: 16.2s	remaining: 54.6s
# 687:	total: 16.3s	remaining: 54.6s
# 688:	total: 16.3s	remaining: 54.6s
# 689:	total: 16.3s	remaining: 54.7s
# 690:	total: 16.4s	remaining: 54.7s
# 691:	total: 16.4s	remaining: 54.7s
# 692:	total: 16.4s	remaining: 54.7s
# 693:	total: 16.5s	remaining: 54.7s
# 694:	total: 16.5s	remaining: 54.8s
# 695:	total: 16.6s	remaining: 54.8s
# 696:	total: 16.6s	remaining: 54.9s
# 697:	total: 16.7s	remaining: 54.9s
# 698:	total: 16.7s	remaining: 55s
# 699:	total: 16.8s	remaining: 55.1s
# 700:	total: 16.8s	remaining: 55.1s
# 701:	total: 16.9s	remaining: 55.2s
# 702:	total: 16.9s	remaining: 55.2s
# 703:	total: 17s	remaining: 55.3s
# 704:	total: 17s	remaining: 55.3s
# 705:	total: 17.1s	remaining: 55.4s
# 706:	total: 17.1s	remaining: 55.5s
# 707:	total: 17.1s	remaining: 55.5s
# 708:	total: 17.2s	remaining: 55.5s
# 709:	total: 17.2s	remaining: 55.6s
# 710:	total: 17.3s	remaining: 55.6s
# 711:	total: 17.3s	remaining: 55.7s
# 712:	total: 17.4s	remaining: 55.7s
# 713:	total: 17.4s	remaining: 55.7s
# 714:	total: 17.5s	remaining: 55.8s
# 715:	total: 17.5s	remaining: 55.9s
# 716:	total: 17.6s	remaining: 55.9s
# 717:	total: 17.6s	remaining: 56s
# 718:	total: 17.7s	remaining: 56s
# 719:	total: 17.7s	remaining: 56.1s
# 720:	total: 17.8s	remaining: 56.2s
# 721:	total: 17.8s	remaining: 56.2s
# 722:	total: 17.8s	remaining: 56.2s
# 723:	total: 17.9s	remaining: 56.3s
# 724:	total: 17.9s	remaining: 56.3s
# 725:	total: 18s	remaining: 56.4s
# 726:	total: 18s	remaining: 56.4s
# 727:	total: 18.1s	remaining: 56.4s
# 728:	total: 18.1s	remaining: 56.4s
# 729:	total: 18.1s	remaining: 56.4s
# 730:	total: 18.1s	remaining: 56.3s
# 731:	total: 18.2s	remaining: 56.3s
# 732:	total: 18.2s	remaining: 56.3s
# 733:	total: 18.2s	remaining: 56.2s
# 734:	total: 18.2s	remaining: 56.2s
# 735:	total: 18.3s	remaining: 56.2s
# 736:	total: 18.3s	remaining: 56.1s
# 737:	total: 18.3s	remaining: 56.1s
# 738:	total: 18.3s	remaining: 56s
# 739:	total: 18.3s	remaining: 56s
# 740:	total: 18.4s	remaining: 56s
# 741:	total: 18.4s	remaining: 55.9s
# 742:	total: 18.4s	remaining: 55.9s
# 743:	total: 18.4s	remaining: 55.9s
# 744:	total: 18.4s	remaining: 55.8s
# 745:	total: 18.5s	remaining: 55.8s
# 746:	total: 18.5s	remaining: 55.8s
# 747:	total: 18.5s	remaining: 55.7s
# 748:	total: 18.5s	remaining: 55.7s
# 749:	total: 18.6s	remaining: 55.7s
# 750:	total: 18.6s	remaining: 55.6s
# 751:	total: 18.6s	remaining: 55.6s
# 752:	total: 18.6s	remaining: 55.6s
# 753:	total: 18.7s	remaining: 55.6s
# 754:	total: 18.7s	remaining: 55.5s
# 755:	total: 18.7s	remaining: 55.5s
# 756:	total: 18.7s	remaining: 55.5s
# 757:	total: 18.7s	remaining: 55.4s
# 758:	total: 18.8s	remaining: 55.4s
# 759:	total: 18.8s	remaining: 55.4s
# 760:	total: 18.8s	remaining: 55.3s
# 761:	total: 18.8s	remaining: 55.3s
# 762:	total: 18.9s	remaining: 55.3s
# 763:	total: 18.9s	remaining: 55.2s
# 764:	total: 18.9s	remaining: 55.2s
# 765:	total: 18.9s	remaining: 55.2s
# 766:	total: 18.9s	remaining: 55.1s
# 767:	total: 19s	remaining: 55.1s
# 768:	total: 19s	remaining: 55.1s
# 769:	total: 19s	remaining: 55.1s
# 770:	total: 19s	remaining: 55s
# 771:	total: 19.1s	remaining: 55s
# 772:	total: 19.1s	remaining: 55s
# 773:	total: 19.1s	remaining: 54.9s
# 774:	total: 19.1s	remaining: 54.9s
# 775:	total: 19.1s	remaining: 54.9s
# 776:	total: 19.2s	remaining: 54.8s
# 777:	total: 19.2s	remaining: 54.8s
# 778:	total: 19.2s	remaining: 54.7s
# 779:	total: 19.2s	remaining: 54.7s
# 780:	total: 19.2s	remaining: 54.7s
# 781:	total: 19.3s	remaining: 54.7s
# 782:	total: 19.3s	remaining: 54.6s
# 783:	total: 19.3s	remaining: 54.6s
# 784:	total: 19.3s	remaining: 54.6s
# 785:	total: 19.4s	remaining: 54.5s
# 786:	total: 19.4s	remaining: 54.5s
# 787:	total: 19.4s	remaining: 54.5s
# 788:	total: 19.4s	remaining: 54.4s
# 789:	total: 19.4s	remaining: 54.4s
# 790:	total: 19.5s	remaining: 54.4s
# 791:	total: 19.5s	remaining: 54.3s
# 792:	total: 19.5s	remaining: 54.3s
# 793:	total: 19.5s	remaining: 54.3s
# 794:	total: 19.6s	remaining: 54.2s
# 795:	total: 19.6s	remaining: 54.2s
# 796:	total: 19.6s	remaining: 54.2s
# 797:	total: 19.6s	remaining: 54.2s
# 798:	total: 19.6s	remaining: 54.1s
# 799:	total: 19.7s	remaining: 54.1s
# 800:	total: 19.7s	remaining: 54s
# 801:	total: 19.7s	remaining: 54s
# 802:	total: 19.7s	remaining: 54s
# 803:	total: 19.8s	remaining: 54s
# 804:	total: 19.8s	remaining: 53.9s
# 805:	total: 19.8s	remaining: 53.9s
# 806:	total: 19.8s	remaining: 53.9s
# 807:	total: 19.9s	remaining: 53.9s
# 808:	total: 19.9s	remaining: 53.8s
# 809:	total: 19.9s	remaining: 53.8s
# 810:	total: 19.9s	remaining: 53.8s
# 811:	total: 19.9s	remaining: 53.7s
# 812:	total: 20s	remaining: 53.7s
# 813:	total: 20s	remaining: 53.7s
# 814:	total: 20s	remaining: 53.6s
# 815:	total: 20s	remaining: 53.6s
# 816:	total: 20s	remaining: 53.6s
# 817:	total: 20.1s	remaining: 53.5s
# 818:	total: 20.1s	remaining: 53.5s
# 819:	total: 20.1s	remaining: 53.5s
# 820:	total: 20.1s	remaining: 53.4s
# 821:	total: 20.2s	remaining: 53.4s
# 822:	total: 20.2s	remaining: 53.4s
# 823:	total: 20.2s	remaining: 53.3s
# 824:	total: 20.2s	remaining: 53.3s
# 825:	total: 20.2s	remaining: 53.3s
# 826:	total: 20.3s	remaining: 53.2s
# 827:	total: 20.3s	remaining: 53.2s
# 828:	total: 20.3s	remaining: 53.2s
# 829:	total: 20.3s	remaining: 53.1s
# 830:	total: 20.3s	remaining: 53.1s
# 831:	total: 20.4s	remaining: 53.1s
# 832:	total: 20.4s	remaining: 53s
# 833:	total: 20.4s	remaining: 53s
# 834:	total: 20.4s	remaining: 53s
# 835:	total: 20.4s	remaining: 52.9s
# 836:	total: 20.5s	remaining: 52.9s
# 837:	total: 20.5s	remaining: 52.9s
# 838:	total: 20.5s	remaining: 52.8s
# 839:	total: 20.5s	remaining: 52.8s
# 840:	total: 20.6s	remaining: 52.8s
# 841:	total: 20.6s	remaining: 52.8s
# 842:	total: 20.6s	remaining: 52.8s
# 843:	total: 20.6s	remaining: 52.7s
# 844:	total: 20.7s	remaining: 52.7s
# 845:	total: 20.7s	remaining: 52.7s
# 846:	total: 20.7s	remaining: 52.6s
# 847:	total: 20.7s	remaining: 52.6s
# 848:	total: 20.7s	remaining: 52.6s
# 849:	total: 20.8s	remaining: 52.6s
# 850:	total: 20.8s	remaining: 52.6s
# 851:	total: 20.8s	remaining: 52.5s
# 852:	total: 20.9s	remaining: 52.5s
# 853:	total: 20.9s	remaining: 52.5s
# 854:	total: 20.9s	remaining: 52.4s
# 855:	total: 20.9s	remaining: 52.4s
# 856:	total: 20.9s	remaining: 52.4s
# 857:	total: 21s	remaining: 52.3s
# 858:	total: 21s	remaining: 52.3s
# 859:	total: 21s	remaining: 52.3s
# 860:	total: 21s	remaining: 52.2s
# 861:	total: 21.1s	remaining: 52.2s
# 862:	total: 21.1s	remaining: 52.2s
# 863:	total: 21.1s	remaining: 52.1s
# 864:	total: 21.1s	remaining: 52.1s
# 865:	total: 21.1s	remaining: 52.1s
# 866:	total: 21.2s	remaining: 52s
# 867:	total: 21.2s	remaining: 52s
# 868:	total: 21.2s	remaining: 52s
# 869:	total: 21.2s	remaining: 52s
# 870:	total: 21.2s	remaining: 51.9s
# 871:	total: 21.3s	remaining: 51.9s
# 872:	total: 21.3s	remaining: 51.9s
# 873:	total: 21.3s	remaining: 51.8s
# 874:	total: 21.3s	remaining: 51.8s
# 875:	total: 21.4s	remaining: 51.8s
# 876:	total: 21.4s	remaining: 51.7s
# 877:	total: 21.4s	remaining: 51.7s
# 878:	total: 21.4s	remaining: 51.7s
# 879:	total: 21.4s	remaining: 51.7s
# 880:	total: 21.5s	remaining: 51.6s
# 881:	total: 21.5s	remaining: 51.6s
# 882:	total: 21.5s	remaining: 51.6s
# 883:	total: 21.5s	remaining: 51.5s
# 884:	total: 21.6s	remaining: 51.5s
# 885:	total: 21.6s	remaining: 51.5s
# 886:	total: 21.6s	remaining: 51.5s
# 887:	total: 21.6s	remaining: 51.4s
# 888:	total: 21.6s	remaining: 51.4s
# 889:	total: 21.7s	remaining: 51.4s
# 890:	total: 21.7s	remaining: 51.3s
# 891:	total: 21.7s	remaining: 51.3s
# 892:	total: 21.7s	remaining: 51.3s
# 893:	total: 21.8s	remaining: 51.2s
# 894:	total: 21.8s	remaining: 51.2s
# 895:	total: 21.8s	remaining: 51.2s
# 896:	total: 21.8s	remaining: 51.1s
# 897:	total: 21.8s	remaining: 51.1s
# 898:	total: 21.9s	remaining: 51.1s
# 899:	total: 21.9s	remaining: 51.1s
# 900:	total: 21.9s	remaining: 51s
# 901:	total: 21.9s	remaining: 51s
# 902:	total: 22s	remaining: 51s
# 903:	total: 22s	remaining: 51s
# 904:	total: 22s	remaining: 50.9s
# 905:	total: 22s	remaining: 50.9s
# 906:	total: 22s	remaining: 50.9s
# 907:	total: 22.1s	remaining: 50.9s
# 908:	total: 22.1s	remaining: 50.8s
# 909:	total: 22.1s	remaining: 50.8s
# 910:	total: 22.1s	remaining: 50.8s
# 911:	total: 22.2s	remaining: 50.7s
# 912:	total: 22.2s	remaining: 50.7s
# 913:	total: 22.2s	remaining: 50.7s
# 914:	total: 22.2s	remaining: 50.6s
# 915:	total: 22.2s	remaining: 50.6s
# 916:	total: 22.3s	remaining: 50.6s
# 917:	total: 22.3s	remaining: 50.6s
# 918:	total: 22.3s	remaining: 50.5s
# 919:	total: 22.3s	remaining: 50.5s
# 920:	total: 22.4s	remaining: 50.5s
# 921:	total: 22.4s	remaining: 50.5s
# 922:	total: 22.4s	remaining: 50.4s
# 923:	total: 22.4s	remaining: 50.4s
# 924:	total: 22.5s	remaining: 50.4s
# 925:	total: 22.5s	remaining: 50.3s
# 926:	total: 22.5s	remaining: 50.3s
# 927:	total: 22.5s	remaining: 50.3s
# 928:	total: 22.5s	remaining: 50.3s
# 929:	total: 22.6s	remaining: 50.2s
# 930:	total: 22.6s	remaining: 50.2s
# 931:	total: 22.6s	remaining: 50.2s
# 932:	total: 22.6s	remaining: 50.2s
# 933:	total: 22.7s	remaining: 50.1s
# 934:	total: 22.7s	remaining: 50.1s
# 935:	total: 22.7s	remaining: 50.1s
# 936:	total: 22.7s	remaining: 50.1s
# 937:	total: 22.8s	remaining: 50s
# 938:	total: 22.8s	remaining: 50s
# 939:	total: 22.8s	remaining: 50s
# 940:	total: 22.8s	remaining: 50s
# 941:	total: 22.9s	remaining: 49.9s
# 942:	total: 22.9s	remaining: 49.9s
# 943:	total: 22.9s	remaining: 49.9s
# 944:	total: 22.9s	remaining: 49.9s
# 945:	total: 22.9s	remaining: 49.8s
# 946:	total: 23s	remaining: 49.8s
# 947:	total: 23s	remaining: 49.8s
# 948:	total: 23s	remaining: 49.7s
# 949:	total: 23s	remaining: 49.7s
# 950:	total: 23.1s	remaining: 49.7s
# 951:	total: 23.1s	remaining: 49.6s
# 952:	total: 23.1s	remaining: 49.6s
# 953:	total: 23.1s	remaining: 49.6s
# 954:	total: 23.1s	remaining: 49.5s
# 955:	total: 23.2s	remaining: 49.5s
# 956:	total: 23.2s	remaining: 49.5s
# 957:	total: 23.2s	remaining: 49.5s
# 958:	total: 23.2s	remaining: 49.4s
# 959:	total: 23.2s	remaining: 49.4s
# 960:	total: 23.3s	remaining: 49.4s
# 961:	total: 23.3s	remaining: 49.3s
# 962:	total: 23.3s	remaining: 49.3s
# 963:	total: 23.3s	remaining: 49.3s
# 964:	total: 23.4s	remaining: 49.3s
# 965:	total: 23.4s	remaining: 49.2s
# 966:	total: 23.4s	remaining: 49.2s
# 967:	total: 23.4s	remaining: 49.2s
# 968:	total: 23.4s	remaining: 49.1s
# 969:	total: 23.5s	remaining: 49.1s
# 970:	total: 23.5s	remaining: 49.1s
# 971:	total: 23.5s	remaining: 49.1s
# 972:	total: 23.5s	remaining: 49s
# 973:	total: 23.6s	remaining: 49s
# 974:	total: 23.6s	remaining: 49s
# 975:	total: 23.6s	remaining: 49s
# 976:	total: 23.6s	remaining: 48.9s
# 977:	total: 23.7s	remaining: 48.9s
# 978:	total: 23.7s	remaining: 48.9s
# 979:	total: 23.7s	remaining: 48.8s
# 980:	total: 23.7s	remaining: 48.8s
# 981:	total: 23.7s	remaining: 48.8s
# 982:	total: 23.8s	remaining: 48.8s
# 983:	total: 23.8s	remaining: 48.7s
# 984:	total: 23.8s	remaining: 48.7s
# 985:	total: 23.8s	remaining: 48.7s
# 986:	total: 23.8s	remaining: 48.6s
# 987:	total: 23.9s	remaining: 48.6s
# 988:	total: 23.9s	remaining: 48.6s
# 989:	total: 23.9s	remaining: 48.6s
# 990:	total: 23.9s	remaining: 48.5s
# 991:	total: 24s	remaining: 48.5s
# 992:	total: 24s	remaining: 48.5s
# 993:	total: 24s	remaining: 48.4s
# 994:	total: 24s	remaining: 48.4s
# 995:	total: 24s	remaining: 48.4s
# 996:	total: 24.1s	remaining: 48.4s
# 997:	total: 24.1s	remaining: 48.3s
# 998:	total: 24.1s	remaining: 48.3s
# 999:	total: 24.1s	remaining: 48.3s
# 1000:	total: 24.2s	remaining: 48.2s
# 1001:	total: 24.2s	remaining: 48.2s
# 1002:	total: 24.2s	remaining: 48.2s
# 1003:	total: 24.2s	remaining: 48.2s
# 1004:	total: 24.2s	remaining: 48.1s
# 1005:	total: 24.3s	remaining: 48.1s
# 1006:	total: 24.3s	remaining: 48.1s
# 1007:	total: 24.3s	remaining: 48s
# 1008:	total: 24.3s	remaining: 48s
# 1009:	total: 24.4s	remaining: 48s
# 1010:	total: 24.4s	remaining: 48s
# 1011:	total: 24.4s	remaining: 47.9s
# 1012:	total: 24.4s	remaining: 47.9s
# 1013:	total: 24.4s	remaining: 47.9s
# 1014:	total: 24.5s	remaining: 47.8s
# 1015:	total: 24.5s	remaining: 47.8s
# 1016:	total: 24.5s	remaining: 47.8s
# 1017:	total: 24.5s	remaining: 47.8s
# 1018:	total: 24.5s	remaining: 47.7s
# 1019:	total: 24.6s	remaining: 47.7s
# 1020:	total: 24.6s	remaining: 47.7s
# 1021:	total: 24.6s	remaining: 47.7s
# 1022:	total: 24.6s	remaining: 47.6s
# 1023:	total: 24.7s	remaining: 47.6s
# 1024:	total: 24.7s	remaining: 47.6s
# 1025:	total: 24.7s	remaining: 47.5s
# 1026:	total: 24.7s	remaining: 47.5s
# 1027:	total: 24.8s	remaining: 47.5s
# 1028:	total: 24.8s	remaining: 47.5s
# 1029:	total: 24.8s	remaining: 47.4s
# 1030:	total: 24.8s	remaining: 47.4s
# 1031:	total: 24.8s	remaining: 47.4s
# 1032:	total: 24.9s	remaining: 47.4s
# 1033:	total: 24.9s	remaining: 47.3s
# 1034:	total: 24.9s	remaining: 47.3s
# 1035:	total: 24.9s	remaining: 47.3s
# 1036:	total: 25s	remaining: 47.2s
# 1037:	total: 25s	remaining: 47.2s
# 1038:	total: 25s	remaining: 47.2s
# 1039:	total: 25s	remaining: 47.2s
# 1040:	total: 25s	remaining: 47.1s
# 1041:	total: 25.1s	remaining: 47.1s
# 1042:	total: 25.1s	remaining: 47.1s
# 1043:	total: 25.1s	remaining: 47.1s
# 1044:	total: 25.1s	remaining: 47s
# 1045:	total: 25.2s	remaining: 47s
# 1046:	total: 25.2s	remaining: 47s
# 1047:	total: 25.2s	remaining: 46.9s
# 1048:	total: 25.2s	remaining: 46.9s
# 1049:	total: 25.2s	remaining: 46.9s
# 1050:	total: 25.3s	remaining: 46.9s
# 1051:	total: 25.3s	remaining: 46.8s
# 1052:	total: 25.3s	remaining: 46.8s
# 1053:	total: 25.3s	remaining: 46.8s
# 1054:	total: 25.4s	remaining: 46.8s
# 1055:	total: 25.4s	remaining: 46.7s
# 1056:	total: 25.4s	remaining: 46.7s
# 1057:	total: 25.4s	remaining: 46.7s
# 1058:	total: 25.4s	remaining: 46.6s
# 1059:	total: 25.5s	remaining: 46.6s
# 1060:	total: 25.5s	remaining: 46.6s
# 1061:	total: 25.5s	remaining: 46.6s
# 1062:	total: 25.5s	remaining: 46.5s
# 1063:	total: 25.6s	remaining: 46.5s
# 1064:	total: 25.6s	remaining: 46.5s
# 1065:	total: 25.6s	remaining: 46.4s
# 1066:	total: 25.6s	remaining: 46.4s
# 1067:	total: 25.6s	remaining: 46.4s
# 1068:	total: 25.7s	remaining: 46.4s
# 1069:	total: 25.7s	remaining: 46.3s
# 1070:	total: 25.7s	remaining: 46.3s
# 1071:	total: 25.7s	remaining: 46.3s
# 1072:	total: 25.8s	remaining: 46.3s
# 1073:	total: 25.8s	remaining: 46.2s
# 1074:	total: 25.8s	remaining: 46.2s
# 1075:	total: 25.8s	remaining: 46.2s
# 1076:	total: 25.9s	remaining: 46.2s
# 1077:	total: 25.9s	remaining: 46.1s
# 1078:	total: 25.9s	remaining: 46.1s
# 1079:	total: 25.9s	remaining: 46.1s
# 1080:	total: 25.9s	remaining: 46.1s
# 1081:	total: 26s	remaining: 46s
# 1082:	total: 26s	remaining: 46s
# 1083:	total: 26s	remaining: 46s
# 1084:	total: 26s	remaining: 45.9s
# 1085:	total: 26s	remaining: 45.9s
# 1086:	total: 26.1s	remaining: 45.9s
# 1087:	total: 26.1s	remaining: 45.9s
# 1088:	total: 26.1s	remaining: 45.8s
# 1089:	total: 26.1s	remaining: 45.8s
# 1090:	total: 26.2s	remaining: 45.8s
# 1091:	total: 26.2s	remaining: 45.7s
# 1092:	total: 26.2s	remaining: 45.7s
# 1093:	total: 26.2s	remaining: 45.7s
# 1094:	total: 26.2s	remaining: 45.7s
# 1095:	total: 26.3s	remaining: 45.6s
# 1096:	total: 26.3s	remaining: 45.6s
# 1097:	total: 26.3s	remaining: 45.6s
# 1098:	total: 26.3s	remaining: 45.5s
# 1099:	total: 26.4s	remaining: 45.5s
# 1100:	total: 26.4s	remaining: 45.5s
# 1101:	total: 26.4s	remaining: 45.5s
# 1102:	total: 26.4s	remaining: 45.4s
# 1103:	total: 26.4s	remaining: 45.4s
# 1104:	total: 26.5s	remaining: 45.4s
# 1105:	total: 26.5s	remaining: 45.4s
# 1106:	total: 26.5s	remaining: 45.3s
# 1107:	total: 26.5s	remaining: 45.3s
# 1108:	total: 26.5s	remaining: 45.3s
# 1109:	total: 26.6s	remaining: 45.2s
# 1110:	total: 26.6s	remaining: 45.2s
# 1111:	total: 26.6s	remaining: 45.2s
# 1112:	total: 26.6s	remaining: 45.2s
# 1113:	total: 26.7s	remaining: 45.1s
# 1114:	total: 26.7s	remaining: 45.1s
# 1115:	total: 26.7s	remaining: 45.1s
# 1116:	total: 26.7s	remaining: 45.1s
# 1117:	total: 26.8s	remaining: 45.1s
# 1118:	total: 26.8s	remaining: 45s
# 1119:	total: 26.8s	remaining: 45s
# 1120:	total: 26.8s	remaining: 45s
# 1121:	total: 26.9s	remaining: 44.9s
# 1122:	total: 26.9s	remaining: 44.9s
# 1123:	total: 26.9s	remaining: 44.9s
# 1124:	total: 26.9s	remaining: 44.9s
# 1125:	total: 26.9s	remaining: 44.8s
# 1126:	total: 27s	remaining: 44.8s
# 1127:	total: 27s	remaining: 44.8s
# 1128:	total: 27s	remaining: 44.8s
# 1129:	total: 27s	remaining: 44.7s
# 1130:	total: 27.1s	remaining: 44.7s
# 1131:	total: 27.1s	remaining: 44.7s
# 1132:	total: 27.1s	remaining: 44.7s
# 1133:	total: 27.1s	remaining: 44.6s
# 1134:	total: 27.2s	remaining: 44.6s
# 1135:	total: 27.2s	remaining: 44.6s
# 1136:	total: 27.2s	remaining: 44.6s
# 1137:	total: 27.2s	remaining: 44.5s
# 1138:	total: 27.2s	remaining: 44.5s
# 1139:	total: 27.3s	remaining: 44.5s
# 1140:	total: 27.3s	remaining: 44.5s
# 1141:	total: 27.3s	remaining: 44.4s
# 1142:	total: 27.3s	remaining: 44.4s
# 1143:	total: 27.3s	remaining: 44.4s
# 1144:	total: 27.4s	remaining: 44.3s
# 1145:	total: 27.4s	remaining: 44.3s
# 1146:	total: 27.4s	remaining: 44.3s
# 1147:	total: 27.4s	remaining: 44.3s
# 1148:	total: 27.5s	remaining: 44.2s
# 1149:	total: 27.5s	remaining: 44.2s
# 1150:	total: 27.5s	remaining: 44.2s
# 1151:	total: 27.5s	remaining: 44.1s
# 1152:	total: 27.5s	remaining: 44.1s
# 1153:	total: 27.6s	remaining: 44.1s
# 1154:	total: 27.6s	remaining: 44.1s
# 1155:	total: 27.6s	remaining: 44s
# 1156:	total: 27.6s	remaining: 44s
# 1157:	total: 27.7s	remaining: 44s
# 1158:	total: 27.7s	remaining: 44s
# 1159:	total: 27.7s	remaining: 43.9s
# 1160:	total: 27.7s	remaining: 43.9s
# 1161:	total: 27.7s	remaining: 43.9s
# 1162:	total: 27.8s	remaining: 43.9s
# 1163:	total: 27.8s	remaining: 43.8s
# 1164:	total: 27.8s	remaining: 43.8s
# 1165:	total: 27.8s	remaining: 43.8s
# 1166:	total: 27.9s	remaining: 43.8s
# 1167:	total: 27.9s	remaining: 43.7s
# 1168:	total: 27.9s	remaining: 43.7s
# 1169:	total: 27.9s	remaining: 43.7s
# 1170:	total: 28s	remaining: 43.7s
# 1171:	total: 28s	remaining: 43.7s
# 1172:	total: 28s	remaining: 43.7s
# 1173:	total: 28.1s	remaining: 43.7s
# 1174:	total: 28.1s	remaining: 43.7s
# 1175:	total: 28.2s	remaining: 43.7s
# 1176:	total: 28.2s	remaining: 43.7s
# 1177:	total: 28.3s	remaining: 43.7s
# 1178:	total: 28.3s	remaining: 43.7s
# 1179:	total: 28.3s	remaining: 43.7s
# 1180:	total: 28.4s	remaining: 43.7s
# 1181:	total: 28.4s	remaining: 43.7s
# 1182:	total: 28.5s	remaining: 43.7s
# 1183:	total: 28.5s	remaining: 43.7s
# 1184:	total: 28.6s	remaining: 43.8s
# 1185:	total: 28.6s	remaining: 43.8s
# 1186:	total: 28.6s	remaining: 43.8s
# 1187:	total: 28.7s	remaining: 43.7s
# 1188:	total: 28.7s	remaining: 43.7s
# 1189:	total: 28.7s	remaining: 43.7s
# 1190:	total: 28.8s	remaining: 43.7s
# 1191:	total: 28.8s	remaining: 43.7s
# 1192:	total: 28.9s	remaining: 43.7s
# 1193:	total: 28.9s	remaining: 43.7s
# 1194:	total: 29s	remaining: 43.8s
# 1195:	total: 29s	remaining: 43.8s
# 1196:	total: 29.1s	remaining: 43.8s
# 1197:	total: 29.1s	remaining: 43.8s
# 1198:	total: 29.2s	remaining: 43.8s
# 1199:	total: 29.2s	remaining: 43.8s
# 1200:	total: 29.3s	remaining: 43.8s
# 1201:	total: 29.3s	remaining: 43.8s
# 1202:	total: 29.4s	remaining: 43.9s
# 1203:	total: 29.4s	remaining: 43.9s
# 1204:	total: 29.5s	remaining: 43.9s
# 1205:	total: 29.5s	remaining: 43.9s
# 1206:	total: 29.5s	remaining: 43.9s
# 1207:	total: 29.6s	remaining: 43.9s
# 1208:	total: 29.7s	remaining: 43.9s
# 1209:	total: 29.7s	remaining: 44s
# 1210:	total: 29.8s	remaining: 44s
# 1211:	total: 29.8s	remaining: 44s
# 1212:	total: 29.8s	remaining: 44s
# 1213:	total: 29.9s	remaining: 43.9s
# 1214:	total: 29.9s	remaining: 43.9s
# 1215:	total: 29.9s	remaining: 43.9s
# 1216:	total: 29.9s	remaining: 43.9s
# 1217:	total: 30s	remaining: 43.8s
# 1218:	total: 30s	remaining: 43.8s
# 1219:	total: 30s	remaining: 43.8s
# 1220:	total: 30s	remaining: 43.8s
# 1221:	total: 30.1s	remaining: 43.7s
# 1222:	total: 30.1s	remaining: 43.7s
# 1223:	total: 30.1s	remaining: 43.7s
# 1224:	total: 30.1s	remaining: 43.7s
# 1225:	total: 30.1s	remaining: 43.6s
# 1226:	total: 30.2s	remaining: 43.6s
# 1227:	total: 30.2s	remaining: 43.6s
# 1228:	total: 30.2s	remaining: 43.5s
# 1229:	total: 30.2s	remaining: 43.5s
# 1230:	total: 30.3s	remaining: 43.5s
# 1231:	total: 30.3s	remaining: 43.5s
# 1232:	total: 30.3s	remaining: 43.5s
# 1233:	total: 30.3s	remaining: 43.4s
# 1234:	total: 30.4s	remaining: 43.4s
# 1235:	total: 30.4s	remaining: 43.4s
# 1236:	total: 30.4s	remaining: 43.3s
# 1237:	total: 30.4s	remaining: 43.3s
# 1238:	total: 30.5s	remaining: 43.3s
# 1239:	total: 30.5s	remaining: 43.3s
# 1240:	total: 30.5s	remaining: 43.2s
# 1241:	total: 30.5s	remaining: 43.2s
# 1242:	total: 30.6s	remaining: 43.2s
# 1243:	total: 30.6s	remaining: 43.2s
# 1244:	total: 30.6s	remaining: 43.1s
# 1245:	total: 30.6s	remaining: 43.1s
# 1246:	total: 30.6s	remaining: 43.1s
# 1247:	total: 30.7s	remaining: 43.1s
# 1248:	total: 30.7s	remaining: 43.1s
# 1249:	total: 30.7s	remaining: 43s
# 1250:	total: 30.8s	remaining: 43s
# 1251:	total: 30.8s	remaining: 43s
# 1252:	total: 30.8s	remaining: 42.9s
# 1253:	total: 30.8s	remaining: 42.9s
# 1254:	total: 30.8s	remaining: 42.9s
# 1255:	total: 30.9s	remaining: 42.9s
# 1256:	total: 30.9s	remaining: 42.9s
# 1257:	total: 30.9s	remaining: 42.8s
# 1258:	total: 30.9s	remaining: 42.8s
# 1259:	total: 31s	remaining: 42.8s
# 1260:	total: 31s	remaining: 42.7s
# 1261:	total: 31s	remaining: 42.7s
# 1262:	total: 31s	remaining: 42.7s
# 1263:	total: 31.1s	remaining: 42.7s
# 1264:	total: 31.1s	remaining: 42.6s
# 1265:	total: 31.1s	remaining: 42.6s
# 1266:	total: 31.1s	remaining: 42.6s
# 1267:	total: 31.2s	remaining: 42.6s
# 1268:	total: 31.2s	remaining: 42.5s
# 1269:	total: 31.2s	remaining: 42.5s
# 1270:	total: 31.2s	remaining: 42.5s
# 1271:	total: 31.2s	remaining: 42.4s
# 1272:	total: 31.3s	remaining: 42.4s
# 1273:	total: 31.3s	remaining: 42.4s
# 1274:	total: 31.3s	remaining: 42.4s
# 1275:	total: 31.3s	remaining: 42.3s
# 1276:	total: 31.4s	remaining: 42.3s
# 1277:	total: 31.4s	remaining: 42.3s
# 1278:	total: 31.4s	remaining: 42.3s
# 1279:	total: 31.4s	remaining: 42.2s
# 1280:	total: 31.5s	remaining: 42.2s
# 1281:	total: 31.5s	remaining: 42.2s
# 1282:	total: 31.5s	remaining: 42.2s
# 1283:	total: 31.5s	remaining: 42.1s
# 1284:	total: 31.5s	remaining: 42.1s
# 1285:	total: 31.6s	remaining: 42.1s
# 1286:	total: 31.6s	remaining: 42s
# 1287:	total: 31.6s	remaining: 42s
# 1288:	total: 31.6s	remaining: 42s
# 1289:	total: 31.7s	remaining: 42s
# 1290:	total: 31.7s	remaining: 41.9s
# 1291:	total: 31.7s	remaining: 41.9s
# 1292:	total: 31.7s	remaining: 41.9s
# 1293:	total: 31.8s	remaining: 41.9s
# 1294:	total: 31.8s	remaining: 41.8s
# 1295:	total: 31.8s	remaining: 41.8s
# 1296:	total: 31.8s	remaining: 41.8s
# 1297:	total: 31.9s	remaining: 41.8s
# 1298:	total: 31.9s	remaining: 41.7s
# 1299:	total: 31.9s	remaining: 41.7s
# 1300:	total: 31.9s	remaining: 41.7s
# 1301:	total: 31.9s	remaining: 41.7s
# 1302:	total: 32s	remaining: 41.6s
# 1303:	total: 32s	remaining: 41.6s
# 1304:	total: 32s	remaining: 41.6s
# 1305:	total: 32s	remaining: 41.5s
# 1306:	total: 32.1s	remaining: 41.5s
# 1307:	total: 32.1s	remaining: 41.5s
# 1308:	total: 32.1s	remaining: 41.5s
# 1309:	total: 32.1s	remaining: 41.4s
# 1310:	total: 32.1s	remaining: 41.4s
# ...
# 2577:	total: 1m 2s	remaining: 10.3s
# 2578:	total: 1m 2s	remaining: 10.2s
# 2579:	total: 1m 2s	remaining: 10.2s
# 2580:	total: 1m 2s	remaining: 10.2s
# 2581:	total: 1m 2s	remaining: 10.2s
# 2582:	total: 1m 2s	remaining: 10.1s
# 2583:	total: 1m 2s	remaining: 10.1s
# 2584:	total: 1m 2s	remaining: 10.1s
# 2585:	total: 1m 2s	remaining: 10.1s
# 2586:	total: 1m 2s	remaining: 10s
# 2587:	total: 1m 2s	remaining: 10s
# 2588:	total: 1m 2s	remaining: 9.98s
# 2589:	total: 1m 2s	remaining: 9.96s
# 2590:	total: 1m 2s	remaining: 9.93s
# 2591:	total: 1m 2s	remaining: 9.91s
# 2592:	total: 1m 2s	remaining: 9.88s
# 2593:	total: 1m 2s	remaining: 9.86s
# 2594:	total: 1m 3s	remaining: 9.83s
# 2595:	total: 1m 3s	remaining: 9.81s
# 2596:	total: 1m 3s	remaining: 9.79s
# 2597:	total: 1m 3s	remaining: 9.77s
# 2598:	total: 1m 3s	remaining: 9.74s
# 2599:	total: 1m 3s	remaining: 9.72s
# 2600:	total: 1m 3s	remaining: 9.71s
# 2601:	total: 1m 3s	remaining: 9.68s
# 2602:	total: 1m 3s	remaining: 9.66s
# 2603:	total: 1m 3s	remaining: 9.64s
# 2604:	total: 1m 3s	remaining: 9.62s
# 2605:	total: 1m 3s	remaining: 9.6s
# 2606:	total: 1m 3s	remaining: 9.58s
# 2607:	total: 1m 3s	remaining: 9.56s
# 2608:	total: 1m 3s	remaining: 9.54s
# 2609:	total: 1m 3s	remaining: 9.52s
# 2610:	total: 1m 3s	remaining: 9.49s
# 2611:	total: 1m 3s	remaining: 9.47s
# 2612:	total: 1m 3s	remaining: 9.45s
# 2613:	total: 1m 3s	remaining: 9.43s
# 2614:	total: 1m 3s	remaining: 9.41s
# 2615:	total: 1m 3s	remaining: 9.39s
# 2616:	total: 1m 4s	remaining: 9.37s
# 2617:	total: 1m 4s	remaining: 9.35s
# 2618:	total: 1m 4s	remaining: 9.33s
# 2619:	total: 1m 4s	remaining: 9.31s
# 2620:	total: 1m 4s	remaining: 9.28s
# 2621:	total: 1m 4s	remaining: 9.26s
# 2622:	total: 1m 4s	remaining: 9.24s
# 2623:	total: 1m 4s	remaining: 9.22s
# 2624:	total: 1m 4s	remaining: 9.2s
# 2625:	total: 1m 4s	remaining: 9.18s
# 2626:	total: 1m 4s	remaining: 9.16s
# 2627:	total: 1m 4s	remaining: 9.13s
# 2628:	total: 1m 4s	remaining: 9.12s
# 2629:	total: 1m 4s	remaining: 9.09s
# 2630:	total: 1m 4s	remaining: 9.07s
# 2631:	total: 1m 4s	remaining: 9.05s
# 2632:	total: 1m 4s	remaining: 9.03s
# 2633:	total: 1m 4s	remaining: 9.01s
# 2634:	total: 1m 4s	remaining: 8.98s
# 2635:	total: 1m 4s	remaining: 8.96s
# 2636:	total: 1m 4s	remaining: 8.93s
# 2637:	total: 1m 4s	remaining: 8.91s
# 2638:	total: 1m 4s	remaining: 8.88s
# 2639:	total: 1m 4s	remaining: 8.86s
# 2640:	total: 1m 4s	remaining: 8.84s
# 2641:	total: 1m 5s	remaining: 8.81s
# 2642:	total: 1m 5s	remaining: 8.78s
# 2643:	total: 1m 5s	remaining: 8.76s
# 2644:	total: 1m 5s	remaining: 8.73s
# 2645:	total: 1m 5s	remaining: 8.71s
# 2646:	total: 1m 5s	remaining: 8.68s
# 2647:	total: 1m 5s	remaining: 8.66s
# 2648:	total: 1m 5s	remaining: 8.63s
# 2649:	total: 1m 5s	remaining: 8.61s
# 2650:	total: 1m 5s	remaining: 8.59s
# 2651:	total: 1m 5s	remaining: 8.56s
# 2652:	total: 1m 5s	remaining: 8.54s
# 2653:	total: 1m 5s	remaining: 8.51s
# 2654:	total: 1m 5s	remaining: 8.49s
# 2655:	total: 1m 5s	remaining: 8.46s
# 2656:	total: 1m 5s	remaining: 8.44s
# 2657:	total: 1m 5s	remaining: 8.41s
# 2658:	total: 1m 5s	remaining: 8.39s
# 2659:	total: 1m 5s	remaining: 8.36s
# 2660:	total: 1m 5s	remaining: 8.34s
# 2661:	total: 1m 5s	remaining: 8.31s
# 2662:	total: 1m 5s	remaining: 8.29s
# 2663:	total: 1m 5s	remaining: 8.26s
# 2664:	total: 1m 5s	remaining: 8.24s
# 2665:	total: 1m 5s	remaining: 8.21s
# 2666:	total: 1m 5s	remaining: 8.19s
# 2667:	total: 1m 5s	remaining: 8.16s
# 2668:	total: 1m 5s	remaining: 8.14s
# 2669:	total: 1m 5s	remaining: 8.11s
# 2670:	total: 1m 5s	remaining: 8.09s
# 2671:	total: 1m 5s	remaining: 8.06s
# 2672:	total: 1m 5s	remaining: 8.04s
# 2673:	total: 1m 5s	remaining: 8.01s
# 2674:	total: 1m 5s	remaining: 7.99s
# 2675:	total: 1m 5s	remaining: 7.96s
# 2676:	total: 1m 5s	remaining: 7.94s
# 2677:	total: 1m 5s	remaining: 7.92s
# 2678:	total: 1m 5s	remaining: 7.89s
# 2679:	total: 1m 5s	remaining: 7.87s
# 2680:	total: 1m 5s	remaining: 7.84s
# 2681:	total: 1m 5s	remaining: 7.82s
# 2682:	total: 1m 5s	remaining: 7.79s
# 2683:	total: 1m 5s	remaining: 7.76s
# 2684:	total: 1m 5s	remaining: 7.74s
# 2685:	total: 1m 6s	remaining: 7.72s
# 2686:	total: 1m 6s	remaining: 7.69s
# 2687:	total: 1m 6s	remaining: 7.67s
# 2688:	total: 1m 6s	remaining: 7.64s
# 2689:	total: 1m 6s	remaining: 7.62s
# 2690:	total: 1m 6s	remaining: 7.59s
# 2691:	total: 1m 6s	remaining: 7.57s
# 2692:	total: 1m 6s	remaining: 7.54s
# 2693:	total: 1m 6s	remaining: 7.52s
# 2694:	total: 1m 6s	remaining: 7.49s
# 2695:	total: 1m 6s	remaining: 7.47s
# 2696:	total: 1m 6s	remaining: 7.44s
# 2697:	total: 1m 6s	remaining: 7.42s
# 2698:	total: 1m 6s	remaining: 7.39s
# 2699:	total: 1m 6s	remaining: 7.37s
# 2700:	total: 1m 6s	remaining: 7.34s
# 2701:	total: 1m 6s	remaining: 7.32s
# 2702:	total: 1m 6s	remaining: 7.29s
# 2703:	total: 1m 6s	remaining: 7.27s
# 2704:	total: 1m 6s	remaining: 7.25s
# 2705:	total: 1m 6s	remaining: 7.22s
# 2706:	total: 1m 6s	remaining: 7.2s
# 2707:	total: 1m 6s	remaining: 7.17s
# 2708:	total: 1m 6s	remaining: 7.15s
# 2709:	total: 1m 6s	remaining: 7.12s
# 2710:	total: 1m 6s	remaining: 7.1s
# 2711:	total: 1m 6s	remaining: 7.07s
# 2712:	total: 1m 6s	remaining: 7.05s
# 2713:	total: 1m 6s	remaining: 7.02s
# 2714:	total: 1m 6s	remaining: 7s
# 2715:	total: 1m 6s	remaining: 6.97s
# 2716:	total: 1m 6s	remaining: 6.95s
# 2717:	total: 1m 6s	remaining: 6.92s
# 2718:	total: 1m 6s	remaining: 6.9s
# 2719:	total: 1m 6s	remaining: 6.87s
# 2720:	total: 1m 6s	remaining: 6.85s
# 2721:	total: 1m 6s	remaining: 6.83s
# 2722:	total: 1m 6s	remaining: 6.8s
# 2723:	total: 1m 6s	remaining: 6.78s
# 2724:	total: 1m 6s	remaining: 6.75s
# 2725:	total: 1m 6s	remaining: 6.73s
# 2726:	total: 1m 6s	remaining: 6.7s
# 2727:	total: 1m 6s	remaining: 6.68s
# 2728:	total: 1m 7s	remaining: 6.65s
# 2729:	total: 1m 7s	remaining: 6.63s
# 2730:	total: 1m 7s	remaining: 6.6s
# 2731:	total: 1m 7s	remaining: 6.58s
# 2732:	total: 1m 7s	remaining: 6.55s
# 2733:	total: 1m 7s	remaining: 6.53s
# 2734:	total: 1m 7s	remaining: 6.5s
# 2735:	total: 1m 7s	remaining: 6.48s
# 2736:	total: 1m 7s	remaining: 6.46s
# 2737:	total: 1m 7s	remaining: 6.43s
# 2738:	total: 1m 7s	remaining: 6.41s
# 2739:	total: 1m 7s	remaining: 6.38s
# 2740:	total: 1m 7s	remaining: 6.36s
# 2741:	total: 1m 7s	remaining: 6.33s
# 2742:	total: 1m 7s	remaining: 6.3s
# 2743:	total: 1m 7s	remaining: 6.28s
# 2744:	total: 1m 7s	remaining: 6.26s
# 2745:	total: 1m 7s	remaining: 6.23s
# 2746:	total: 1m 7s	remaining: 6.21s
# 2747:	total: 1m 7s	remaining: 6.18s
# 2748:	total: 1m 7s	remaining: 6.16s
# 2749:	total: 1m 7s	remaining: 6.13s
# 2750:	total: 1m 7s	remaining: 6.11s
# 2751:	total: 1m 7s	remaining: 6.08s
# 2752:	total: 1m 7s	remaining: 6.06s
# 2753:	total: 1m 7s	remaining: 6.03s
# 2754:	total: 1m 7s	remaining: 6.01s
# 2755:	total: 1m 7s	remaining: 5.98s
# 2756:	total: 1m 7s	remaining: 5.96s
# 2757:	total: 1m 7s	remaining: 5.93s
# 2758:	total: 1m 7s	remaining: 5.91s
# 2759:	total: 1m 7s	remaining: 5.89s
# 2760:	total: 1m 7s	remaining: 5.86s
# 2761:	total: 1m 7s	remaining: 5.84s
# 2762:	total: 1m 7s	remaining: 5.81s
# 2763:	total: 1m 7s	remaining: 5.79s
# 2764:	total: 1m 7s	remaining: 5.76s
# 2765:	total: 1m 7s	remaining: 5.74s
# 2766:	total: 1m 7s	remaining: 5.71s
# 2767:	total: 1m 7s	remaining: 5.69s
# 2768:	total: 1m 7s	remaining: 5.66s
# 2769:	total: 1m 7s	remaining: 5.64s
# 2770:	total: 1m 7s	remaining: 5.62s
# 2771:	total: 1m 7s	remaining: 5.59s
# 2772:	total: 1m 7s	remaining: 5.57s
# 2773:	total: 1m 8s	remaining: 5.54s
# 2774:	total: 1m 8s	remaining: 5.52s
# 2775:	total: 1m 8s	remaining: 5.49s
# 2776:	total: 1m 8s	remaining: 5.47s
# 2777:	total: 1m 8s	remaining: 5.44s
# 2778:	total: 1m 8s	remaining: 5.42s
# 2779:	total: 1m 8s	remaining: 5.39s
# 2780:	total: 1m 8s	remaining: 5.37s
# 2781:	total: 1m 8s	remaining: 5.34s
# 2782:	total: 1m 8s	remaining: 5.32s
# 2783:	total: 1m 8s	remaining: 5.29s
# 2784:	total: 1m 8s	remaining: 5.27s
# 2785:	total: 1m 8s	remaining: 5.24s
# 2786:	total: 1m 8s	remaining: 5.22s
# 2787:	total: 1m 8s	remaining: 5.2s
# 2788:	total: 1m 8s	remaining: 5.17s
# 2789:	total: 1m 8s	remaining: 5.15s
# 2790:	total: 1m 8s	remaining: 5.12s
# 2791:	total: 1m 8s	remaining: 5.1s
# 2792:	total: 1m 8s	remaining: 5.07s
# 2793:	total: 1m 8s	remaining: 5.05s
# 2794:	total: 1m 8s	remaining: 5.02s
# 2795:	total: 1m 8s	remaining: 5s
# 2796:	total: 1m 8s	remaining: 4.97s
# 2797:	total: 1m 8s	remaining: 4.95s
# 2798:	total: 1m 8s	remaining: 4.92s
# 2799:	total: 1m 8s	remaining: 4.9s
# 2800:	total: 1m 8s	remaining: 4.88s
# 2801:	total: 1m 8s	remaining: 4.85s
# 2802:	total: 1m 8s	remaining: 4.83s
# 2803:	total: 1m 8s	remaining: 4.8s
# 2804:	total: 1m 8s	remaining: 4.78s
# 2805:	total: 1m 8s	remaining: 4.75s
# 2806:	total: 1m 8s	remaining: 4.73s
# 2807:	total: 1m 8s	remaining: 4.7s
# 2808:	total: 1m 8s	remaining: 4.68s
# 2809:	total: 1m 8s	remaining: 4.65s
# 2810:	total: 1m 8s	remaining: 4.63s
# 2811:	total: 1m 8s	remaining: 4.61s
# 2812:	total: 1m 8s	remaining: 4.58s
# 2813:	total: 1m 8s	remaining: 4.56s
# 2814:	total: 1m 8s	remaining: 4.53s
# 2815:	total: 1m 8s	remaining: 4.51s
# 2816:	total: 1m 8s	remaining: 4.48s
# 2817:	total: 1m 9s	remaining: 4.46s
# 2818:	total: 1m 9s	remaining: 4.43s
# 2819:	total: 1m 9s	remaining: 4.41s
# 2820:	total: 1m 9s	remaining: 4.38s
# 2821:	total: 1m 9s	remaining: 4.36s
# 2822:	total: 1m 9s	remaining: 4.33s
# 2823:	total: 1m 9s	remaining: 4.31s
# 2824:	total: 1m 9s	remaining: 4.29s
# 2825:	total: 1m 9s	remaining: 4.26s
# 2826:	total: 1m 9s	remaining: 4.24s
# 2827:	total: 1m 9s	remaining: 4.21s
# 2828:	total: 1m 9s	remaining: 4.19s
# 2829:	total: 1m 9s	remaining: 4.16s
# 2830:	total: 1m 9s	remaining: 4.14s
# 2831:	total: 1m 9s	remaining: 4.11s
# 2832:	total: 1m 9s	remaining: 4.09s
# 2833:	total: 1m 9s	remaining: 4.06s
# 2834:	total: 1m 9s	remaining: 4.04s
# 2835:	total: 1m 9s	remaining: 4.01s
# 2836:	total: 1m 9s	remaining: 3.99s
# 2837:	total: 1m 9s	remaining: 3.96s
# 2838:	total: 1m 9s	remaining: 3.94s
# 2839:	total: 1m 9s	remaining: 3.92s
# 2840:	total: 1m 9s	remaining: 3.89s
# 2841:	total: 1m 9s	remaining: 3.87s
# 2842:	total: 1m 9s	remaining: 3.84s
# 2843:	total: 1m 9s	remaining: 3.82s
# 2844:	total: 1m 9s	remaining: 3.79s
# 2845:	total: 1m 9s	remaining: 3.77s
# 2846:	total: 1m 9s	remaining: 3.74s
# 2847:	total: 1m 9s	remaining: 3.72s
# 2848:	total: 1m 9s	remaining: 3.69s
# 2849:	total: 1m 9s	remaining: 3.67s
# 2850:	total: 1m 9s	remaining: 3.65s
# 2851:	total: 1m 9s	remaining: 3.62s
# 2852:	total: 1m 9s	remaining: 3.6s
# 2853:	total: 1m 9s	remaining: 3.57s
# 2854:	total: 1m 9s	remaining: 3.55s
# 2855:	total: 1m 9s	remaining: 3.52s
# 2856:	total: 1m 9s	remaining: 3.5s
# 2857:	total: 1m 9s	remaining: 3.47s
# 2858:	total: 1m 9s	remaining: 3.45s
# 2859:	total: 1m 9s	remaining: 3.42s
# 2860:	total: 1m 9s	remaining: 3.4s
# 2861:	total: 1m 10s	remaining: 3.38s
# 2862:	total: 1m 10s	remaining: 3.35s
# 2863:	total: 1m 10s	remaining: 3.33s
# 2864:	total: 1m 10s	remaining: 3.3s
# 2865:	total: 1m 10s	remaining: 3.28s
# 2866:	total: 1m 10s	remaining: 3.25s
# 2867:	total: 1m 10s	remaining: 3.23s
# 2868:	total: 1m 10s	remaining: 3.2s
# 2869:	total: 1m 10s	remaining: 3.18s
# 2870:	total: 1m 10s	remaining: 3.15s
# 2871:	total: 1m 10s	remaining: 3.13s
# 2872:	total: 1m 10s	remaining: 3.11s
# 2873:	total: 1m 10s	remaining: 3.08s
# 2874:	total: 1m 10s	remaining: 3.06s
# 2875:	total: 1m 10s	remaining: 3.03s
# 2876:	total: 1m 10s	remaining: 3.01s
# 2877:	total: 1m 10s	remaining: 2.98s
# 2878:	total: 1m 10s	remaining: 2.96s
# 2879:	total: 1m 10s	remaining: 2.93s
# 2880:	total: 1m 10s	remaining: 2.91s
# 2881:	total: 1m 10s	remaining: 2.88s
# 2882:	total: 1m 10s	remaining: 2.86s
# 2883:	total: 1m 10s	remaining: 2.84s
# 2884:	total: 1m 10s	remaining: 2.81s
# 2885:	total: 1m 10s	remaining: 2.79s
# 2886:	total: 1m 10s	remaining: 2.76s
# 2887:	total: 1m 10s	remaining: 2.74s
# 2888:	total: 1m 10s	remaining: 2.71s
# 2889:	total: 1m 10s	remaining: 2.69s
# 2890:	total: 1m 10s	remaining: 2.66s
# 2891:	total: 1m 10s	remaining: 2.64s
# 2892:	total: 1m 10s	remaining: 2.62s
# 2893:	total: 1m 10s	remaining: 2.59s
# 2894:	total: 1m 10s	remaining: 2.57s
# 2895:	total: 1m 10s	remaining: 2.54s
# 2896:	total: 1m 10s	remaining: 2.52s
# 2897:	total: 1m 10s	remaining: 2.49s
# 2898:	total: 1m 10s	remaining: 2.47s
# 2899:	total: 1m 10s	remaining: 2.44s
# 2900:	total: 1m 10s	remaining: 2.42s
# 2901:	total: 1m 10s	remaining: 2.39s
# 2902:	total: 1m 10s	remaining: 2.37s
# 2903:	total: 1m 10s	remaining: 2.35s
# 2904:	total: 1m 10s	remaining: 2.32s
# 2905:	total: 1m 11s	remaining: 2.3s
# 2906:	total: 1m 11s	remaining: 2.27s
# 2907:	total: 1m 11s	remaining: 2.25s
# 2908:	total: 1m 11s	remaining: 2.22s
# 2909:	total: 1m 11s	remaining: 2.2s
# 2910:	total: 1m 11s	remaining: 2.17s
# 2911:	total: 1m 11s	remaining: 2.15s
# 2912:	total: 1m 11s	remaining: 2.13s
# 2913:	total: 1m 11s	remaining: 2.1s
# 2914:	total: 1m 11s	remaining: 2.08s
# 2915:	total: 1m 11s	remaining: 2.05s
# 2916:	total: 1m 11s	remaining: 2.03s
# 2917:	total: 1m 11s	remaining: 2s
# 2918:	total: 1m 11s	remaining: 1.98s
# 2919:	total: 1m 11s	remaining: 1.95s
# 2920:	total: 1m 11s	remaining: 1.93s
# 2921:	total: 1m 11s	remaining: 1.91s
# 2922:	total: 1m 11s	remaining: 1.88s
# 2923:	total: 1m 11s	remaining: 1.86s
# 2924:	total: 1m 11s	remaining: 1.83s
# 2925:	total: 1m 11s	remaining: 1.81s
# 2926:	total: 1m 11s	remaining: 1.78s
# 2927:	total: 1m 11s	remaining: 1.76s
# 2928:	total: 1m 11s	remaining: 1.73s
# 2929:	total: 1m 11s	remaining: 1.71s
# 2930:	total: 1m 11s	remaining: 1.69s
# 2931:	total: 1m 11s	remaining: 1.66s
# 2932:	total: 1m 11s	remaining: 1.64s
# 2933:	total: 1m 11s	remaining: 1.61s
# 2934:	total: 1m 11s	remaining: 1.59s
# 2935:	total: 1m 11s	remaining: 1.56s
# 2936:	total: 1m 11s	remaining: 1.54s
# 2937:	total: 1m 11s	remaining: 1.51s
# 2938:	total: 1m 11s	remaining: 1.49s
# 2939:	total: 1m 11s	remaining: 1.46s
# 2940:	total: 1m 11s	remaining: 1.44s
# 2941:	total: 1m 11s	remaining: 1.42s
# 2942:	total: 1m 11s	remaining: 1.39s
# 2943:	total: 1m 11s	remaining: 1.37s
# 2944:	total: 1m 11s	remaining: 1.34s
# 2945:	total: 1m 11s	remaining: 1.32s
# 2946:	total: 1m 11s	remaining: 1.29s
# 2947:	total: 1m 11s	remaining: 1.27s
# 2948:	total: 1m 11s	remaining: 1.25s
# 2949:	total: 1m 12s	remaining: 1.22s
# 2950:	total: 1m 12s	remaining: 1.2s
# 2951:	total: 1m 12s	remaining: 1.17s
# 2952:	total: 1m 12s	remaining: 1.15s
# 2953:	total: 1m 12s	remaining: 1.12s
# 2954:	total: 1m 12s	remaining: 1.1s
# 2955:	total: 1m 12s	remaining: 1.07s
# 2956:	total: 1m 12s	remaining: 1.05s
# 2957:	total: 1m 12s	remaining: 1.02s
# 2958:	total: 1m 12s	remaining: 1s
# 2959:	total: 1m 12s	remaining: 976ms
# 2960:	total: 1m 12s	remaining: 952ms
# 2961:	total: 1m 12s	remaining: 927ms
# 2962:	total: 1m 12s	remaining: 903ms
# 2963:	total: 1m 12s	remaining: 879ms
# 2964:	total: 1m 12s	remaining: 854ms
# 2965:	total: 1m 12s	remaining: 830ms
# 2966:	total: 1m 12s	remaining: 805ms
# 2967:	total: 1m 12s	remaining: 781ms
# 2968:	total: 1m 12s	remaining: 756ms
# 2969:	total: 1m 12s	remaining: 732ms
# 2970:	total: 1m 12s	remaining: 708ms
# 2971:	total: 1m 12s	remaining: 683ms
# 2972:	total: 1m 12s	remaining: 659ms
# 2973:	total: 1m 12s	remaining: 634ms
# 2974:	total: 1m 12s	remaining: 610ms
# 2975:	total: 1m 12s	remaining: 586ms
# 2976:	total: 1m 12s	remaining: 561ms
# 2977:	total: 1m 12s	remaining: 537ms
# 2978:	total: 1m 12s	remaining: 512ms
# 2979:	total: 1m 12s	remaining: 488ms
# 2980:	total: 1m 12s	remaining: 463ms
# 2981:	total: 1m 12s	remaining: 439ms
# 2982:	total: 1m 12s	remaining: 415ms
# 2983:	total: 1m 12s	remaining: 390ms
# 2984:	total: 1m 12s	remaining: 366ms
# 2985:	total: 1m 12s	remaining: 341ms
# 2986:	total: 1m 12s	remaining: 317ms
# 2987:	total: 1m 12s	remaining: 293ms
# 2988:	total: 1m 12s	remaining: 268ms
# 2989:	total: 1m 12s	remaining: 244ms
# 2990:	total: 1m 12s	remaining: 219ms
# 2991:	total: 1m 12s	remaining: 195ms
# 2992:	total: 1m 12s	remaining: 171ms
# 2993:	total: 1m 13s	remaining: 146ms
# 2994:	total: 1m 13s	remaining: 122ms
# 2995:	total: 1m 13s	remaining: 97.6ms
# 2996:	total: 1m 13s	remaining: 73.2ms
# 2997:	total: 1m 13s	remaining: 48.8ms
# 2998:	total: 1m 13s	remaining: 24.4ms
# 2999:	total: 1m 13s	remaining: 0us
# [[1633  351  112  252    1]
#  [ 356 1191  244  118    2]
#  [  63  167  905   22    0]
#  [ 190   42   37  684    2]
#  [   0    0    1    0  477]]
# 0.7138686131386861
#               precision    recall  f1-score   support
#
#          1.0       0.73      0.70      0.71      2349
#          2.0       0.68      0.62      0.65      1911
#          3.0       0.70      0.78      0.74      1157
#          4.0       0.64      0.72      0.67       955
#          5.0       0.99      1.00      0.99       478
#
#     accuracy                           0.71      6850
#    macro avg       0.75      0.76      0.75      6850
# weighted avg       0.71      0.71      0.71      6850

# %%
from sklearn.naive_bayes import GaussianNB

nb=GaussianNB()

#training the model
nb.fit(X_train,y_train)

#testing the model
y_pred=nb.predict(X_test)
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.4475912408759124

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(max_leaf_nodes=50, random_state=0)
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.5204379562043796

# %%
for i in range (1,20):
  knn = KNeighborsClassifier(n_neighbors=i)
  knn.fit(X_train_res, y_train_res)
  y_pred4 = knn.predict(X_test)
  #print(confusion_matrix(y_test,y_pred4))
  print(accuracy_score(y_test,y_pred4))
  #print(classification_report(y_test,y_pred4))
# Out:
# 0.9208759124087591
# 0.843065693430657
# 0.7856934306569343
# 0.7640875912408759
# 0.7316788321167883
# 0.7218978102189781
# 0.7013138686131387
# 0.6908029197080292
# 0.675036496350365
# 0.6684671532846715
# 0.6537226277372262
# 0.6454014598540146
# 0.6345985401459854
# 0.6272992700729927
# 0.6157664233576642
# 0.6102189781021898
# 0.6032116788321168
# 0.6014598540145986
# 0.5943065693430657
